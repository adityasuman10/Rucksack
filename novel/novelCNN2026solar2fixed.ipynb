# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.model_selection import train_test_split
import seaborn as sns
from PIL import Image
import random
import keras
from keras import layers, models, optimizers, callbacks

# Set seeds for reproducibility
random.seed(42)
np.random.seed(42)
keras.utils.set_random_seed(42)

# ============================================================================
# CONFIGURATION - Tune these for your needs
# ============================================================================
IMAGE_SIZE = 128
NUM_CLASSES = 6
BATCH_SIZE = 16
LEARNING_RATE = 1e-3
WEIGHT_DECAY = 1e-5
EPOCHS = 100
DATASET_PATH = r"/content/drive/MyDrive/concave"
VALIDATION_SPLIT = 0.2  # 20% for validation

# Model complexity settings
USE_LIGHTWEIGHT = True
MULTISCALE_STAGES = [1]

# Debug settings
DEBUG_MODE = True

# ============================================================================
# STRATIFIED DATA LOADING - FIXED VERSION
# ============================================================================
def load_dataset_stratified(dataset_path, validation_split=0.2, image_size=128, batch_size=16):
    """
    Load dataset with stratified splitting to ensure all classes are represented
    """
    print("Loading dataset with stratified splitting...")

    # Get all image paths and labels
    image_paths = []
    labels = []
    class_names = sorted(os.listdir(dataset_path))
    class_to_idx = {cls_name: idx for idx, cls_name in enumerate(class_names)}

    for class_name in class_names:
        class_dir = os.path.join(dataset_path, class_name)
        if not os.path.isdir(class_dir):
            continue

        for img_name in os.listdir(class_dir):
            if img_name.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
                image_paths.append(os.path.join(class_dir, img_name))
                labels.append(class_to_idx[class_name])

    image_paths = np.array(image_paths)
    labels = np.array(labels)

    print(f"Total images found: {len(image_paths)}")
    print(f"Classes: {class_names}")

    # Stratified split
    train_paths, val_paths, train_labels, val_labels = train_test_split(
        image_paths, labels,
        test_size=validation_split,
        stratify=labels,  # This ensures balanced class distribution
        random_state=42
    )

    print(f"\nTraining samples: {len(train_paths)}")
    print(f"Validation samples: {len(val_paths)}")

    # Check distribution
    print("\nClass distribution in training set:")
    for i, class_name in enumerate(class_names):
        count = np.sum(train_labels == i)
        print(f"  Class {i} ({class_name}): {count} samples")

    print("\nClass distribution in validation set:")
    for i, class_name in enumerate(class_names):
        count = np.sum(val_labels == i)
        print(f"  Class {i} ({class_name}): {count} samples")

    # Create TF datasets using tf.data
    import tensorflow as tf

    def create_tf_dataset(paths, labels, is_training=False):
        """Create TF dataset from paths and labels"""
        def load_and_preprocess(path, label):
            # Read and decode image
            img = tf.io.read_file(path)
            img = tf.image.decode_jpeg(img, channels=3)
            img = tf.image.resize(img, [image_size, image_size])
            img = tf.cast(img, tf.float32) / 255.0  # Normalize to [0, 1]
            return img, label

        # Create dataset from paths and labels
        dataset = tf.data.Dataset.from_tensor_slices((paths, labels))

        if is_training:
            dataset = dataset.shuffle(buffer_size=1000)

        dataset = dataset.map(load_and_preprocess, num_parallel_calls=tf.data.AUTOTUNE)
        dataset = dataset.batch(batch_size)
        dataset = dataset.prefetch(buffer_size=tf.data.AUTOTUNE)

        return dataset

    train_dataset = create_tf_dataset(train_paths, train_labels, is_training=True)
    val_dataset = create_tf_dataset(val_paths, val_labels, is_training=False)

    return train_dataset, val_dataset, class_names

# ============================================================================
# DATA AUGMENTATION
# ============================================================================
def create_augmentation_layer():
    """Data augmentation for training"""
    return keras.Sequential([
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.1),
        layers.RandomContrast(0.1),
    ], name='augmentation')

# ============================================================================
# LIGHTWEIGHT MULTI-SCALE CONV
# ============================================================================
def lightweight_multiscale_conv(x, channels, stride=1):
    """Multi-scale convolution with 4 branches"""
    # Branch 1: 3x3
    branch_3x3 = layers.DepthwiseConv2D(3, strides=stride, padding='same', use_bias=False)(x)
    branch_3x3 = layers.BatchNormalization()(branch_3x3)

    # Branch 2: 5x5
    branch_5x5 = layers.DepthwiseConv2D(5, strides=stride, padding='same', use_bias=False)(x)
    branch_5x5 = layers.BatchNormalization()(branch_5x5)

    # Branch 3: Horizontal 1x7
    branch_h = layers.DepthwiseConv2D((1, 7), strides=stride, padding='same', use_bias=False)(x)
    branch_h = layers.BatchNormalization()(branch_h)

    # Branch 4: Vertical 7x1
    branch_v = layers.DepthwiseConv2D((7, 1), strides=stride, padding='same', use_bias=False)(x)
    branch_v = layers.BatchNormalization()(branch_v)

    # Concatenate and fuse
    multi_scale = layers.Concatenate(axis=-1)([branch_3x3, branch_5x5, branch_h, branch_v])
    multi_scale = layers.Conv2D(channels, 1, padding='same', use_bias=False)(multi_scale)
    multi_scale = layers.BatchNormalization()(multi_scale)
    multi_scale = layers.Activation('gelu')(multi_scale)

    return multi_scale

# ============================================================================
# ECA BLOCK
# ============================================================================
def eca_block(x, channels, k_size=3):
    """Efficient Channel Attention"""
    eca = layers.GlobalAveragePooling2D()(x)
    eca = layers.Reshape((channels, 1))(eca)
    eca = layers.Conv1D(1, kernel_size=k_size, padding='same', use_bias=False)(eca)
    eca = layers.Reshape((1, 1, channels))(eca)
    eca = layers.Activation('sigmoid')(eca)
    return layers.Multiply()([x, eca])

# ============================================================================
# MBCONV BLOCK
# ============================================================================
def optimized_mbconv_block(x, in_channels, out_channels, expansion_factor=4,
                          stride=1, use_multiscale=False):
    """MBConv block with optional multi-scale"""
    input_tensor = x
    expanded_channels = in_channels * expansion_factor

    # Expansion
    if expansion_factor != 1:
        x = layers.Conv2D(expanded_channels, 1, padding='same', use_bias=False)(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation('gelu')(x)

    # Depthwise (multi-scale or standard)
    if use_multiscale:
        x = lightweight_multiscale_conv(x, expanded_channels, stride)
    else:
        x = layers.DepthwiseConv2D(3, strides=stride, padding='same', use_bias=False)(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation('gelu')(x)

    # ECA attention
    x = eca_block(x, expanded_channels)

    # Projection
    x = layers.Conv2D(out_channels, 1, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)

    # Residual
    if stride == 1 and in_channels == out_channels:
        x = layers.Add()([input_tensor, x])

    return x

# ============================================================================
# TRANSFORMER BLOCK
# ============================================================================
def lightweight_transformer_block(x, in_channels, out_channels, stride=1):
    """Lightweight transformer block"""
    input_tensor = x

    # Handle channel changes
    if in_channels != out_channels:
        input_tensor = layers.Conv2D(out_channels, 1, use_bias=False)(input_tensor)
        input_tensor = layers.BatchNormalization()(input_tensor)
        x = layers.Conv2D(out_channels, 1, use_bias=False)(x)
        x = layers.BatchNormalization()(x)

    # Handle spatial changes
    if stride > 1:
        x = layers.AveragePooling2D(stride)(x)
        input_tensor = layers.AveragePooling2D(stride)(input_tensor)

    # Attention
    attn = layers.LayerNormalization(epsilon=1e-6)(x)
    attn = layers.Conv2D(out_channels, 3, padding='same')(attn)
    attn = layers.Activation('gelu')(attn)
    attn = layers.Dropout(0.15)(attn)
    x = layers.Add()([x, attn])

    # FFN
    ff = layers.LayerNormalization(epsilon=1e-6)(x)
    ff = layers.Conv2D(out_channels * 2, 1)(ff)
    ff = layers.Activation('gelu')(ff)
    ff = layers.Dropout(0.15)(ff)
    ff = layers.Conv2D(out_channels, 1)(ff)
    x = layers.Add()([x, ff])

    # Final residual
    x = layers.Add()([input_tensor, x])

    return x

# ============================================================================
# MODEL CREATION
# ============================================================================
def create_optimized_coatnet(num_classes, image_size, use_lightweight=True):
    """CoAtNet model with proper data flow"""
    inputs = layers.Input(shape=(image_size, image_size, 3))

    # Apply augmentation as a layer (only active during training)
    x = create_augmentation_layer()(inputs)

    # Stem
    stem_channels = 32 if use_lightweight else 48
    x = layers.Conv2D(stem_channels, 3, strides=2, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('gelu')(x)

    # Stage 1: MBConv (64x64)
    use_ms_s1 = 1 in MULTISCALE_STAGES
    x = optimized_mbconv_block(x, stem_channels, stem_channels,
                               expansion_factor=4, use_multiscale=use_ms_s1)

    # Stage 2: MBConv with stride (32x32)
    use_ms_s2 = 2 in MULTISCALE_STAGES
    x = optimized_mbconv_block(x, stem_channels, stem_channels * 2,
                               expansion_factor=4, stride=2, use_multiscale=use_ms_s2)

    # Stage 3: Transformer (16x16)
    x = lightweight_transformer_block(x, stem_channels * 2, stem_channels * 4, stride=2)

    # Stage 4: Transformer (8x8)
    x = lightweight_transformer_block(x, stem_channels * 4, stem_channels * 6, stride=2)

    # Classification head
    x = layers.LayerNormalization(epsilon=1e-6)(x)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.4)(x)
    x = layers.Dense(128, activation='gelu', kernel_regularizer=keras.regularizers.l2(1e-4))(x)
    x = layers.Dropout(0.3)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inputs, outputs, name='OptimizedCoAtNet')
    return model

# ============================================================================
# CUSTOM CALLBACK
# ============================================================================
class DebugCallback(callbacks.Callback):
    """Custom callback to monitor training"""
    def on_epoch_end(self, epoch, logs=None):
        if DEBUG_MODE and epoch % 5 == 0:
            print(f"\n[DEBUG] Epoch {epoch+1}:")
            print(f"  Train Loss: {logs['loss']:.4f}, Train Acc: {logs['accuracy']:.4f}")
            print(f"  Val Loss: {logs['val_loss']:.4f}, Val Acc: {logs['val_accuracy']:.4f}")
            print(f"  Learning Rate: {self.model.optimizer.learning_rate.numpy():.6f}")

# ============================================================================
# TRAINING FUNCTIONS
# ============================================================================
def train_model(model, train_data, val_data, class_names):
    """Train with improved settings"""

    optimizer = optimizers.AdamW(
        learning_rate=LEARNING_RATE,
        weight_decay=WEIGHT_DECAY
    )

    model.compile(
        optimizer=optimizer,
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    print("=" * 70)
    model.summary()
    print("=" * 70)

    # Callbacks
    early_stopping = callbacks.EarlyStopping(
        monitor='val_loss',
        patience=25,
        restore_best_weights=True,
        verbose=1
    )

    reduce_lr = callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=8,
        min_lr=1e-7,
        verbose=1
    )

    model_checkpoint = callbacks.ModelCheckpoint(
        'best_optimized_model.keras',
        monitor='val_loss',
        save_best_only=True,
        verbose=1
    )

    debug_callback = DebugCallback()

    # Train
    history = model.fit(
        train_data,
        validation_data=val_data,
        epochs=EPOCHS,
        callbacks=[early_stopping, reduce_lr, model_checkpoint, debug_callback],
        verbose=1
    )

    return history

def plot_training_history(history):
    """Plot training curves"""
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

    epochs = range(1, len(history.history['loss']) + 1)

    # Loss
    ax1.plot(epochs, history.history['loss'], 'b-', label='Training Loss', linewidth=2)
    ax1.plot(epochs, history.history['val_loss'], 'r-', label='Validation Loss', linewidth=2)
    ax1.set_title('Model Loss', fontsize=14, fontweight='bold')
    ax1.set_xlabel('Epoch', fontsize=12)
    ax1.set_ylabel('Loss', fontsize=12)
    ax1.legend(fontsize=11)
    ax1.grid(True, alpha=0.3)

    # Accuracy
    ax2.plot(epochs, history.history['accuracy'], 'b-', label='Training Accuracy', linewidth=2)
    ax2.plot(epochs, history.history['val_accuracy'], 'r-', label='Validation Accuracy', linewidth=2)
    ax2.set_title('Model Accuracy', fontsize=14, fontweight='bold')
    ax2.set_xlabel('Epoch', fontsize=12)
    ax2.set_ylabel('Accuracy', fontsize=12)
    ax2.legend(fontsize=11)
    ax2.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig('training_history.png', dpi=150)
    plt.show()

def evaluate_model(model, test_data, class_names):
    """Evaluate model performance"""

    # Get predictions
    y_pred = model.predict(test_data, verbose=1)
    y_pred_classes = np.argmax(y_pred, axis=1)

    # Get true labels
    y_true = []
    for _, labels in test_data:
        y_true.extend(labels.numpy())
    y_true = np.array(y_true)

    # Metrics
    accuracy = accuracy_score(y_true, y_pred_classes)
    print("\n" + "=" * 70)
    print(f"TEST ACCURACY: {accuracy:.4f} ({accuracy*100:.2f}%)")
    print("=" * 70)

    # Classification report
    print("\nClassification Report:")
    print(classification_report(
        y_true,
        y_pred_classes,
        target_names=class_names,
        labels=list(range(len(class_names))),
        zero_division=0
    ))

    # Per-class accuracy
    print("\nPer-Class Accuracy:")
    cm = confusion_matrix(y_true, y_pred_classes, labels=list(range(len(class_names))))
    for i, class_name in enumerate(class_names):
        class_acc = cm[i, i] / cm[i].sum() if cm[i].sum() > 0 else 0
        print(f"  {class_name}: {class_acc:.4f} ({class_acc*100:.2f}%)")

    # Confusion matrix plot
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names, yticklabels=class_names,
                cbar_kws={'label': 'Count'})
    plt.title('Confusion Matrix', fontsize=16, fontweight='bold', pad=20)
    plt.xlabel('Predicted Label', fontsize=12)
    plt.ylabel('True Label', fontsize=12)
    plt.tight_layout()
    plt.savefig('confusion_matrix.png', dpi=150)
    plt.show()

    return accuracy, cm

# ============================================================================
# MAIN PIPELINE
# ============================================================================
def main():
    """Main training pipeline"""
    print("\n" + "=" * 70)
    print("OPTIMIZED ISAR CoAtNet - STRATIFIED SPLIT VERSION")
    print("=" * 70)
    print(f"Configuration:")
    print(f"  Image Size: {IMAGE_SIZE}x{IMAGE_SIZE}")
    print(f"  Batch Size: {BATCH_SIZE}")
    print(f"  Learning Rate: {LEARNING_RATE}")
    print(f"  Weight Decay: {WEIGHT_DECAY}")
    print(f"  Validation Split: {VALIDATION_SPLIT}")
    print(f"  Lightweight Mode: {USE_LIGHTWEIGHT}")
    print(f"  Multi-scale Stages: {MULTISCALE_STAGES}")
    print("=" * 70 + "\n")

    # Check dataset
    if not os.path.exists(DATASET_PATH):
        print(f"❌ Dataset path {DATASET_PATH} does not exist!")
        return

    # Load data with stratified splitting
    try:
        train_dataset, val_dataset, class_names = load_dataset_stratified(
            DATASET_PATH,
            validation_split=VALIDATION_SPLIT,
            image_size=IMAGE_SIZE,
            batch_size=BATCH_SIZE
        )

        num_classes = len(class_names)
        print(f"\n✓ Successfully loaded {num_classes} classes with balanced splits")

    except Exception as e:
        print(f"❌ Error loading dataset: {e}")
        import traceback
        traceback.print_exc()
        return

    # Create model
    print("\nCreating optimized model...\n")
    model = create_optimized_coatnet(num_classes, IMAGE_SIZE, USE_LIGHTWEIGHT)

    # Train
    print("Starting training...\n")
    try:
        history = train_model(model, train_dataset, val_dataset, class_names)

        # Plot results
        print("\nGenerating training plots...")
        plot_training_history(history)

        # Evaluate
        print("\nEvaluating model...")
        accuracy, cm = evaluate_model(model, val_dataset, class_names)

        # Save metrics
        metrics_df = pd.DataFrame({
            'epoch': range(len(history.history['loss'])),
            'train_loss': history.history['loss'],
            'val_loss': history.history['val_loss'],
            'train_accuracy': history.history['accuracy'],
            'val_accuracy': history.history['val_accuracy']
        })
        metrics_df.to_csv('training_metrics.csv', index=False)
        print("\n✓ Metrics saved to 'training_metrics.csv'")

        print("\n" + "=" * 70)
        print("Training completed successfully!")
        print("=" * 70)

    except Exception as e:
        print(f"\n❌ Error during training: {e}")
        import traceback
        traceback.print_exc()

if __name__ == "__main__":
    main()
# Out:
# ======================================================================
# OPTIMIZED ISAR CoAtNet - STRATIFIED SPLIT VERSION
# ======================================================================
# Configuration:
#   Image Size: 128x128
#   Batch Size: 16
#   Learning Rate: 0.001
#   Weight Decay: 1e-05
#   Validation Split: 0.2
#   Lightweight Mode: True
#   Multi-scale Stages: [1]
# ======================================================================
#
# Loading dataset with stratified splitting...
# Total images found: 899
# Classes: ['Moon_jellyfish', 'barrel_jellyfish', 'blue_jellyfish', 'compass_jellyfish', 'lions_mane_jellyfish', 'mauve_stinger_jellyfish']
#
# Training samples: 719
# Validation samples: 180
#
# Class distribution in training set:
#   Class 0 (Moon_jellyfish): 120 samples
#   Class 1 (barrel_jellyfish): 120 samples
#   Class 2 (blue_jellyfish): 119 samples
#   Class 3 (compass_jellyfish): 120 samples
#   Class 4 (lions_mane_jellyfish): 120 samples
#   Class 5 (mauve_stinger_jellyfish): 120 samples
#
# Class distribution in validation set:
#   Class 0 (Moon_jellyfish): 30 samples
#   Class 1 (barrel_jellyfish): 30 samples
#   Class 2 (blue_jellyfish): 30 samples
#   Class 3 (compass_jellyfish): 30 samples
#   Class 4 (lions_mane_jellyfish): 30 samples
#   Class 5 (mauve_stinger_jellyfish): 30 samples
#
# ✓ Successfully loaded 6 classes with balanced splits
#
# Creating optimized model...
#
# Starting training...
#
# ======================================================================
# Model: "OptimizedCoAtNet"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_6       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ augmentation        │ (None, 128, 128,  │          0 │ input_layer_6[0]… │
# │ (Sequential)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_48 (Conv2D)  │ (None, 64, 64,    │        864 │ augmentation[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_48[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_33       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_49 (Conv2D)  │ (None, 64, 64,    │      4,096 │ activation_33[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_49[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_34       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_15 │ (None, 64, 64,    │      1,152 │ activation_34[0]… │
# │ (DepthwiseConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_16 │ (None, 64, 64,    │      3,200 │ activation_34[0]… │
# │ (DepthwiseConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_17 │ (None, 64, 64,    │        896 │ activation_34[0]… │
# │ (DepthwiseConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_18 │ (None, 64, 64,    │        896 │ activation_34[0]… │
# │ (DepthwiseConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Concatenate)       │ 512)              │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_50 (Conv2D)  │ (None, 64, 64,    │     65,536 │ concatenate_3[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_50[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_35       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ activation_35[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_12          │ (None, 128, 1)    │          0 │ global_average_p… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_6 (Conv1D)   │ (None, 128, 1)    │          3 │ reshape_12[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_13          │ (None, 1, 1, 128) │          0 │ conv1d_6[0][0]    │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_36       │ (None, 1, 1, 128) │          0 │ reshape_13[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_6          │ (None, 64, 64,    │          0 │ activation_35[0]… │
# │ (Multiply)          │ 128)              │            │ activation_36[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_51 (Conv2D)  │ (None, 64, 64,    │      4,096 │ multiply_6[0][0]  │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_51[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_21 (Add)        │ (None, 64, 64,    │          0 │ activation_33[0]… │
# │                     │ 32)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_52 (Conv2D)  │ (None, 64, 64,    │      4,096 │ add_21[0][0]      │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ conv2d_52[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_37       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_19 │ (None, 32, 32,    │      1,152 │ activation_37[0]… │
# │ (DepthwiseConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_38       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ activation_38[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_14          │ (None, 128, 1)    │          0 │ global_average_p… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_7 (Conv1D)   │ (None, 128, 1)    │          3 │ reshape_14[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_15          │ (None, 1, 1, 128) │          0 │ conv1d_7[0][0]    │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_39       │ (None, 1, 1, 128) │          0 │ reshape_15[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_7          │ (None, 32, 32,    │          0 │ activation_38[0]… │
# │ (Multiply)          │ 128)              │            │ activation_39[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_53 (Conv2D)  │ (None, 32, 32,    │      8,192 │ multiply_7[0][0]  │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_53[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_55 (Conv2D)  │ (None, 32, 32,    │      8,192 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_55[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_… │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (AveragePooling2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 16, 16,    │        256 │ average_pooling2… │
# │ (LayerNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_56 (Conv2D)  │ (None, 16, 16,    │    147,584 │ layer_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_40       │ (None, 16, 16,    │          0 │ conv2d_56[0][0]   │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_18          │ (None, 16, 16,    │          0 │ activation_40[0]… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_22 (Add)        │ (None, 16, 16,    │          0 │ average_pooling2… │
# │                     │ 128)              │            │ dropout_18[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 16, 16,    │        256 │ add_22[0][0]      │
# │ (LayerNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_57 (Conv2D)  │ (None, 16, 16,    │     33,024 │ layer_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_41       │ (None, 16, 16,    │          0 │ conv2d_57[0][0]   │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_54 (Conv2D)  │ (None, 32, 32,    │      8,192 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_19          │ (None, 16, 16,    │          0 │ activation_41[0]… │
# │ (Dropout)           │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_54[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_58 (Conv2D)  │ (None, 16, 16,    │     32,896 │ dropout_19[0][0]  │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_… │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (AveragePooling2D)  │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_23 (Add)        │ (None, 16, 16,    │          0 │ add_22[0][0],     │
# │                     │ 128)              │            │ conv2d_58[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_24 (Add)        │ (None, 16, 16,    │          0 │ average_pooling2… │
# │                     │ 128)              │            │ add_23[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_60 (Conv2D)  │ (None, 16, 16,    │     24,576 │ add_24[0][0]      │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        768 │ conv2d_60[0][0]   │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_… │ (None, 8, 8, 192) │          0 │ batch_normalizat… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 8, 8, 192) │        384 │ average_pooling2… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_61 (Conv2D)  │ (None, 8, 8, 192) │    331,968 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_42       │ (None, 8, 8, 192) │          0 │ conv2d_61[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_20          │ (None, 8, 8, 192) │          0 │ activation_42[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_25 (Add)        │ (None, 8, 8, 192) │          0 │ average_pooling2… │
# │                     │                   │            │ dropout_20[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 8, 8, 192) │        384 │ add_25[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_62 (Conv2D)  │ (None, 8, 8, 384) │     74,112 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_43       │ (None, 8, 8, 384) │          0 │ conv2d_62[0][0]   │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_59 (Conv2D)  │ (None, 16, 16,    │     24,576 │ add_24[0][0]      │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_21          │ (None, 8, 8, 384) │          0 │ activation_43[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        768 │ conv2d_59[0][0]   │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_63 (Conv2D)  │ (None, 8, 8, 192) │     73,920 │ dropout_21[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ average_pooling2d_… │ (None, 8, 8, 192) │          0 │ batch_normalizat… │
# │ (AveragePooling2D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_26 (Add)        │ (None, 8, 8, 192) │          0 │ add_25[0][0],     │
# │                     │                   │            │ conv2d_63[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_27 (Add)        │ (None, 8, 8, 192) │          0 │ average_pooling2… │
# │                     │                   │            │ add_26[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 8, 8, 192) │        384 │ add_27[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 192)       │          0 │ layer_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_22          │ (None, 192)       │          0 │ global_average_p… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_6 (Dense)     │ (None, 128)       │     24,704 │ dropout_22[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_23          │ (None, 128)       │          0 │ dense_6[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_7 (Dense)     │ (None, 6)         │        774 │ dropout_23[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 887,532 (3.39 MB)
#  Trainable params: 883,948 (3.37 MB)
#  Non-trainable params: 3,584 (14.00 KB)
# ======================================================================
# Epoch 1/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step - accuracy: 0.2954 - loss: 1.8733
# Epoch 1: val_loss improved from inf to 2.84326, saving model to best_optimized_model.keras
#
# [DEBUG] Epoch 1:
#   Train Loss: 1.8494, Train Acc: 0.2962
#   Val Loss: 2.8433, Val Acc: 0.1667
#   Learning Rate: 0.001000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 46s 529ms/step - accuracy: 0.2954 - loss: 1.8728 - val_accuracy: 0.1667 - val_loss: 2.8433 - learning_rate: 0.0010
# Epoch 2/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.3990 - loss: 1.5788
# Epoch 2: val_loss did not improve from 2.84326
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 162ms/step - accuracy: 0.3987 - loss: 1.5792 - val_accuracy: 0.1667 - val_loss: 3.3005 - learning_rate: 0.0010
# Epoch 3/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.4063 - loss: 1.5485
# Epoch 3: val_loss improved from 2.84326 to 2.31128, saving model to best_optimized_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 148ms/step - accuracy: 0.4059 - loss: 1.5486 - val_accuracy: 0.2167 - val_loss: 2.3113 - learning_rate: 0.0010
# Epoch 4/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.4484 - loss: 1.4281
# Epoch 4: val_loss did not improve from 2.31128
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 153ms/step - accuracy: 0.4479 - loss: 1.4283 - val_accuracy: 0.1667 - val_loss: 2.9885 - learning_rate: 0.0010
# Epoch 5/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.4824 - loss: 1.3249
# Epoch 5: val_loss did not improve from 2.31128
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - accuracy: 0.4820 - loss: 1.3260 - val_accuracy: 0.1833 - val_loss: 2.5401 - learning_rate: 0.0010
# Epoch 6/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.4677 - loss: 1.3386
# Epoch 6: val_loss did not improve from 2.31128
#
# [DEBUG] Epoch 6:
#   Train Loss: 1.3538, Train Acc: 0.4757
#   Val Loss: 3.2228, Val Acc: 0.1667
#   Learning Rate: 0.001000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 153ms/step - accuracy: 0.4679 - loss: 1.3389 - val_accuracy: 0.1667 - val_loss: 3.2228 - learning_rate: 0.0010
# Epoch 7/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.4587 - loss: 1.3280
# Epoch 7: val_loss did not improve from 2.31128
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - accuracy: 0.4587 - loss: 1.3284 - val_accuracy: 0.1889 - val_loss: 2.5128 - learning_rate: 0.0010
# Epoch 8/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.5195 - loss: 1.2895
# Epoch 8: val_loss did not improve from 2.31128
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 154ms/step - accuracy: 0.5195 - loss: 1.2889 - val_accuracy: 0.1667 - val_loss: 2.3541 - learning_rate: 0.0010
# Epoch 9/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.4958 - loss: 1.2755
# Epoch 9: val_loss improved from 2.31128 to 2.02680, saving model to best_optimized_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 148ms/step - accuracy: 0.4963 - loss: 1.2746 - val_accuracy: 0.2389 - val_loss: 2.0268 - learning_rate: 0.0010
# Epoch 10/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.5014 - loss: 1.2006
# Epoch 10: val_loss improved from 2.02680 to 1.75192, saving model to best_optimized_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 163ms/step - accuracy: 0.5013 - loss: 1.2016 - val_accuracy: 0.2389 - val_loss: 1.7519 - learning_rate: 0.0010
# Epoch 11/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.5713 - loss: 1.1418
# Epoch 11: val_loss improved from 1.75192 to 1.56692, saving model to best_optimized_model.keras
#
# [DEBUG] Epoch 11:
#   Train Loss: 1.1164, Train Acc: 0.5661
#   Val Loss: 1.5669, Val Acc: 0.3833
#   Learning Rate: 0.001000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 146ms/step - accuracy: 0.5712 - loss: 1.1413 - val_accuracy: 0.3833 - val_loss: 1.5669 - learning_rate: 0.0010
# Epoch 12/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.5759 - loss: 1.0899
# Epoch 12: val_loss improved from 1.56692 to 1.46981, saving model to best_optimized_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 194ms/step - accuracy: 0.5757 - loss: 1.0902 - val_accuracy: 0.4222 - val_loss: 1.4698 - learning_rate: 0.0010
# Epoch 13/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.5833 - loss: 1.0971
# Epoch 13: val_loss improved from 1.46981 to 1.25410, saving model to best_optimized_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 160ms/step - accuracy: 0.5837 - loss: 1.0961 - val_accuracy: 0.5667 - val_loss: 1.2541 - learning_rate: 0.0010
# Epoch 14/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.6027 - loss: 1.0356
# Epoch 14: val_loss improved from 1.25410 to 1.17727, saving model to best_optimized_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 147ms/step - accuracy: 0.6024 - loss: 1.0368 - val_accuracy: 0.5111 - val_loss: 1.1773 - learning_rate: 0.0010
# Epoch 15/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.6178 - loss: 1.0140
# Epoch 15: val_loss improved from 1.17727 to 0.98177, saving model to best_optimized_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 0.6175 - loss: 1.0150 - val_accuracy: 0.5778 - val_loss: 0.9818 - learning_rate: 0.0010
# Epoch 16/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.6064 - loss: 0.9491
# Epoch 16: val_loss did not improve from 0.98177
#
# [DEBUG] Epoch 16:
#   Train Loss: 0.9396, Train Acc: 0.6259
#   Val Loss: 1.0945, Val Acc: 0.5444
#   Learning Rate: 0.001000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 138ms/step - accuracy: 0.6068 - loss: 0.9489 - val_accuracy: 0.5444 - val_loss: 1.0945 - learning_rate: 0.0010
# Epoch 17/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.6896 - loss: 0.8463
# Epoch 17: val_loss did not improve from 0.98177
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 153ms/step - accuracy: 0.6892 - loss: 0.8467 - val_accuracy: 0.6167 - val_loss: 1.0144 - learning_rate: 0.0010
# Epoch 18/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.6513 - loss: 0.9090
# Epoch 18: val_loss did not improve from 0.98177
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 140ms/step - accuracy: 0.6514 - loss: 0.9087 - val_accuracy: 0.5611 - val_loss: 1.2384 - learning_rate: 0.0010
# Epoch 19/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.7089 - loss: 0.7305
# Epoch 19: val_loss improved from 0.98177 to 0.96948, saving model to best_optimized_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 0.7083 - loss: 0.7316 - val_accuracy: 0.6611 - val_loss: 0.9695 - learning_rate: 0.0010
# Epoch 20/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.6901 - loss: 0.8046
# Epoch 20: val_loss improved from 0.96948 to 0.93829, saving model to best_optimized_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 149ms/step - accuracy: 0.6895 - loss: 0.8065 - val_accuracy: 0.6944 - val_loss: 0.9383 - learning_rate: 0.0010
# Epoch 21/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.6770 - loss: 0.8081
# Epoch 21: val_loss did not improve from 0.93829
#
# [DEBUG] Epoch 21:
#   Train Loss: 0.8473, Train Acc: 0.6704
#   Val Loss: 1.1873, Val Acc: 0.5889
#   Learning Rate: 0.001000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 153ms/step - accuracy: 0.6768 - loss: 0.8090 - val_accuracy: 0.5889 - val_loss: 1.1873 - learning_rate: 0.0010
# Epoch 22/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.7181 - loss: 0.7252
# Epoch 22: val_loss did not improve from 0.93829
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - accuracy: 0.7180 - loss: 0.7256 - val_accuracy: 0.5444 - val_loss: 1.3224 - learning_rate: 0.0010
# Epoch 23/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.7557 - loss: 0.6567
# Epoch 23: val_loss improved from 0.93829 to 0.91150, saving model to best_optimized_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 0.7552 - loss: 0.6580 - val_accuracy: 0.6944 - val_loss: 0.9115 - learning_rate: 0.0010
# Epoch 24/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.7101 - loss: 0.8247
# Epoch 24: val_loss did not improve from 0.91150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - accuracy: 0.7097 - loss: 0.8252 - val_accuracy: 0.5333 - val_loss: 1.6072 - learning_rate: 0.0010
# Epoch 25/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.7543 - loss: 0.6557
# Epoch 25: val_loss did not improve from 0.91150
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 154ms/step - accuracy: 0.7538 - loss: 0.6573 - val_accuracy: 0.5944 - val_loss: 1.1093 - learning_rate: 0.0010
# Epoch 26/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.7652 - loss: 0.6698
# Epoch 26: val_loss improved from 0.91150 to 0.84887, saving model to best_optimized_model.keras
#
# [DEBUG] Epoch 26:
#   Train Loss: 0.6774, Train Acc: 0.7413
#   Val Loss: 0.8489, Val Acc: 0.7278
#   Learning Rate: 0.001000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 148ms/step - accuracy: 0.7647 - loss: 0.6699 - val_accuracy: 0.7278 - val_loss: 0.8489 - learning_rate: 0.0010
# Epoch 27/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.7201 - loss: 0.7332
# Epoch 27: val_loss improved from 0.84887 to 0.72676, saving model to best_optimized_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 160ms/step - accuracy: 0.7200 - loss: 0.7339 - val_accuracy: 0.7389 - val_loss: 0.7268 - learning_rate: 0.0010
# Epoch 28/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.7931 - loss: 0.5916
# Epoch 28: val_loss improved from 0.72676 to 0.68234, saving model to best_optimized_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 148ms/step - accuracy: 0.7927 - loss: 0.5920 - val_accuracy: 0.7778 - val_loss: 0.6823 - learning_rate: 0.0010
# Epoch 29/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.7792 - loss: 0.5908
# Epoch 29: val_loss did not improve from 0.68234
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 153ms/step - accuracy: 0.7792 - loss: 0.5911 - val_accuracy: 0.5944 - val_loss: 1.3494 - learning_rate: 0.0010
# Epoch 30/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.7405 - loss: 0.6685
# Epoch 30: val_loss did not improve from 0.68234
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - accuracy: 0.7410 - loss: 0.6677 - val_accuracy: 0.7333 - val_loss: 0.7579 - learning_rate: 0.0010
# Epoch 31/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.8241 - loss: 0.5105
# Epoch 31: val_loss did not improve from 0.68234
#
# [DEBUG] Epoch 31:
#   Train Loss: 0.5432, Train Acc: 0.8095
#   Val Loss: 1.1515, Val Acc: 0.6000
#   Learning Rate: 0.001000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 156ms/step - accuracy: 0.8238 - loss: 0.5112 - val_accuracy: 0.6000 - val_loss: 1.1515 - learning_rate: 0.0010
# Epoch 32/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.7831 - loss: 0.5997
# Epoch 32: val_loss did not improve from 0.68234
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - accuracy: 0.7833 - loss: 0.5995 - val_accuracy: 0.6667 - val_loss: 1.0792 - learning_rate: 0.0010
# Epoch 33/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.7893 - loss: 0.5503
# Epoch 33: val_loss did not improve from 0.68234
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 152ms/step - accuracy: 0.7893 - loss: 0.5500 - val_accuracy: 0.8000 - val_loss: 0.7757 - learning_rate: 0.0010
# Epoch 34/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.8322 - loss: 0.5227
# Epoch 34: val_loss improved from 0.68234 to 0.65459, saving model to best_optimized_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 149ms/step - accuracy: 0.8325 - loss: 0.5222 - val_accuracy: 0.7444 - val_loss: 0.6546 - learning_rate: 0.0010
# Epoch 35/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.8526 - loss: 0.4173
# Epoch 35: val_loss did not improve from 0.65459
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 153ms/step - accuracy: 0.8527 - loss: 0.4174 - val_accuracy: 0.7667 - val_loss: 0.7083 - learning_rate: 0.0010
# Epoch 36/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.8073 - loss: 0.5204
# Epoch 36: val_loss did not improve from 0.65459
#
# [DEBUG] Epoch 36:
#   Train Loss: 0.5466, Train Acc: 0.7914
#   Val Loss: 0.9320, Val Acc: 0.7444
#   Learning Rate: 0.001000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - accuracy: 0.8070 - loss: 0.5210 - val_accuracy: 0.7444 - val_loss: 0.9320 - learning_rate: 0.0010
# Epoch 37/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.8260 - loss: 0.5413
# Epoch 37: val_loss improved from 0.65459 to 0.56014, saving model to best_optimized_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 149ms/step - accuracy: 0.8257 - loss: 0.5415 - val_accuracy: 0.8056 - val_loss: 0.5601 - learning_rate: 0.0010
# Epoch 38/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.8525 - loss: 0.4187
# Epoch 38: val_loss did not improve from 0.56014
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 150ms/step - accuracy: 0.8524 - loss: 0.4187 - val_accuracy: 0.7556 - val_loss: 0.8249 - learning_rate: 0.0010
# Epoch 39/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.8605 - loss: 0.4096
# Epoch 39: val_loss did not improve from 0.56014
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - accuracy: 0.8595 - loss: 0.4114 - val_accuracy: 0.7556 - val_loss: 0.6620 - learning_rate: 0.0010
# Epoch 40/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.8077 - loss: 0.5177
# Epoch 40: val_loss did not improve from 0.56014
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 155ms/step - accuracy: 0.8077 - loss: 0.5179 - val_accuracy: 0.8222 - val_loss: 0.6256 - learning_rate: 0.0010
# Epoch 41/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.8835 - loss: 0.3600
# Epoch 41: val_loss did not improve from 0.56014
#
# [DEBUG] Epoch 41:
#   Train Loss: 0.3882, Train Acc: 0.8595
#   Val Loss: 0.7210, Val Acc: 0.8278
#   Learning Rate: 0.001000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - accuracy: 0.8829 - loss: 0.3606 - val_accuracy: 0.8278 - val_loss: 0.7210 - learning_rate: 0.0010
# Epoch 42/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.8286 - loss: 0.4103
# Epoch 42: val_loss did not improve from 0.56014
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 152ms/step - accuracy: 0.8284 - loss: 0.4113 - val_accuracy: 0.7500 - val_loss: 0.8108 - learning_rate: 0.0010
# Epoch 43/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.8301 - loss: 0.4574
# Epoch 43: val_loss did not improve from 0.56014
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 138ms/step - accuracy: 0.8301 - loss: 0.4575 - val_accuracy: 0.7611 - val_loss: 0.8125 - learning_rate: 0.0010
# Epoch 44/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.8628 - loss: 0.3809
# Epoch 44: val_loss did not improve from 0.56014
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 162ms/step - accuracy: 0.8625 - loss: 0.3814 - val_accuracy: 0.8167 - val_loss: 0.7824 - learning_rate: 0.0010
# Epoch 45/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.8842 - loss: 0.3311
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 45: val_loss did not improve from 0.56014
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 137ms/step - accuracy: 0.8838 - loss: 0.3318 - val_accuracy: 0.8111 - val_loss: 0.6374 - learning_rate: 0.0010
# Epoch 46/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.8814 - loss: 0.3446
# Epoch 46: val_loss did not improve from 0.56014
#
# [DEBUG] Epoch 46:
#   Train Loss: 0.2976, Train Acc: 0.9013
#   Val Loss: 0.6066, Val Acc: 0.8278
#   Learning Rate: 0.000500
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 152ms/step - accuracy: 0.8819 - loss: 0.3435 - val_accuracy: 0.8278 - val_loss: 0.6066 - learning_rate: 5.0000e-04
# Epoch 47/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9447 - loss: 0.2060
# Epoch 47: val_loss did not improve from 0.56014
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - accuracy: 0.9446 - loss: 0.2061 - val_accuracy: 0.8333 - val_loss: 0.5610 - learning_rate: 5.0000e-04
# Epoch 48/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9537 - loss: 0.1886
# Epoch 48: val_loss improved from 0.56014 to 0.46810, saving model to best_optimized_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 159ms/step - accuracy: 0.9534 - loss: 0.1890 - val_accuracy: 0.8667 - val_loss: 0.4681 - learning_rate: 5.0000e-04
# Epoch 49/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9350 - loss: 0.2069
# Epoch 49: val_loss improved from 0.46810 to 0.46254, saving model to best_optimized_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 146ms/step - accuracy: 0.9348 - loss: 0.2076 - val_accuracy: 0.8778 - val_loss: 0.4625 - learning_rate: 5.0000e-04
# Epoch 50/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.9326 - loss: 0.2386
# Epoch 50: val_loss improved from 0.46254 to 0.43639, saving model to best_optimized_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 163ms/step - accuracy: 0.9327 - loss: 0.2385 - val_accuracy: 0.8500 - val_loss: 0.4364 - learning_rate: 5.0000e-04
# Epoch 51/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.9263 - loss: 0.2375
# Epoch 51: val_loss did not improve from 0.43639
#
# [DEBUG] Epoch 51:
#   Train Loss: 0.2278, Train Acc: 0.9291
#   Val Loss: 0.5288, Val Acc: 0.8833
#   Learning Rate: 0.000500
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - accuracy: 0.9264 - loss: 0.2373 - val_accuracy: 0.8833 - val_loss: 0.5288 - learning_rate: 5.0000e-04
# Epoch 52/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.9247 - loss: 0.1838
# Epoch 52: val_loss did not improve from 0.43639
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 156ms/step - accuracy: 0.9247 - loss: 0.1840 - val_accuracy: 0.8500 - val_loss: 0.4820 - learning_rate: 5.0000e-04
# Epoch 53/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.9417 - loss: 0.1858
# Epoch 53: val_loss did not improve from 0.43639
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - accuracy: 0.9417 - loss: 0.1857 - val_accuracy: 0.8667 - val_loss: 0.5191 - learning_rate: 5.0000e-04
# Epoch 54/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9580 - loss: 0.1477
# Epoch 54: val_loss improved from 0.43639 to 0.43258, saving model to best_optimized_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 0.9579 - loss: 0.1480 - val_accuracy: 0.8944 - val_loss: 0.4326 - learning_rate: 5.0000e-04
# Epoch 55/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.9577 - loss: 0.1435
# Epoch 55: val_loss did not improve from 0.43258
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - accuracy: 0.9577 - loss: 0.1433 - val_accuracy: 0.8389 - val_loss: 0.5966 - learning_rate: 5.0000e-04
# Epoch 56/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9712 - loss: 0.1334
# Epoch 56: val_loss did not improve from 0.43258
#
# [DEBUG] Epoch 56:
#   Train Loss: 0.1661, Train Acc: 0.9555
#   Val Loss: 0.6162, Val Acc: 0.8778
#   Learning Rate: 0.000500
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 165ms/step - accuracy: 0.9708 - loss: 0.1341 - val_accuracy: 0.8778 - val_loss: 0.6162 - learning_rate: 5.0000e-04
# Epoch 57/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9507 - loss: 0.1582
# Epoch 57: val_loss did not improve from 0.43258
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 139ms/step - accuracy: 0.9509 - loss: 0.1577 - val_accuracy: 0.8944 - val_loss: 0.4335 - learning_rate: 5.0000e-04
# Epoch 58/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9722 - loss: 0.1143
# Epoch 58: val_loss did not improve from 0.43258
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 154ms/step - accuracy: 0.9718 - loss: 0.1147 - val_accuracy: 0.8722 - val_loss: 0.5705 - learning_rate: 5.0000e-04
# Epoch 59/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.9529 - loss: 0.1550
# Epoch 59: val_loss did not improve from 0.43258
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 140ms/step - accuracy: 0.9527 - loss: 0.1554 - val_accuracy: 0.8722 - val_loss: 0.5041 - learning_rate: 5.0000e-04
# Epoch 60/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9522 - loss: 0.1823
# Epoch 60: val_loss improved from 0.43258 to 0.37617, saving model to best_optimized_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 162ms/step - accuracy: 0.9520 - loss: 0.1825 - val_accuracy: 0.9000 - val_loss: 0.3762 - learning_rate: 5.0000e-04
# Epoch 61/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.9620 - loss: 0.1644
# Epoch 61: val_loss did not improve from 0.37617
#
# [DEBUG] Epoch 61:
#   Train Loss: 0.1663, Train Acc: 0.9555
#   Val Loss: 0.5026, Val Acc: 0.8833
#   Learning Rate: 0.000500
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - accuracy: 0.9619 - loss: 0.1645 - val_accuracy: 0.8833 - val_loss: 0.5026 - learning_rate: 5.0000e-04
# Epoch 62/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9550 - loss: 0.1640
# Epoch 62: val_loss did not improve from 0.37617
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 153ms/step - accuracy: 0.9550 - loss: 0.1643 - val_accuracy: 0.8167 - val_loss: 0.7183 - learning_rate: 5.0000e-04
# Epoch 63/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.9555 - loss: 0.1604
# Epoch 63: val_loss did not improve from 0.37617
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - accuracy: 0.9556 - loss: 0.1603 - val_accuracy: 0.8889 - val_loss: 0.5394 - learning_rate: 5.0000e-04
# Epoch 64/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9512 - loss: 0.1655
# Epoch 64: val_loss did not improve from 0.37617
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 153ms/step - accuracy: 0.9512 - loss: 0.1655 - val_accuracy: 0.8722 - val_loss: 0.5489 - learning_rate: 5.0000e-04
# Epoch 65/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.9509 - loss: 0.1792
# Epoch 65: val_loss did not improve from 0.37617
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 154ms/step - accuracy: 0.9506 - loss: 0.1799 - val_accuracy: 0.8889 - val_loss: 0.5241 - learning_rate: 5.0000e-04
# Epoch 66/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.9737 - loss: 0.1108
# Epoch 66: val_loss did not improve from 0.37617
#
# [DEBUG] Epoch 66:
#   Train Loss: 0.1585, Train Acc: 0.9569
#   Val Loss: 0.5854, Val Acc: 0.8500
#   Learning Rate: 0.000500
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - accuracy: 0.9734 - loss: 0.1119 - val_accuracy: 0.8500 - val_loss: 0.5854 - learning_rate: 5.0000e-04
# Epoch 67/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9481 - loss: 0.1979
# Epoch 67: val_loss improved from 0.37617 to 0.36446, saving model to best_optimized_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 0.9481 - loss: 0.1971 - val_accuracy: 0.9000 - val_loss: 0.3645 - learning_rate: 5.0000e-04
# Epoch 68/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.9466 - loss: 0.1664
# Epoch 68: val_loss did not improve from 0.36446
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 139ms/step - accuracy: 0.9467 - loss: 0.1662 - val_accuracy: 0.8833 - val_loss: 0.4278 - learning_rate: 5.0000e-04
# Epoch 69/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9532 - loss: 0.1860
# Epoch 69: val_loss did not improve from 0.36446
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 149ms/step - accuracy: 0.9533 - loss: 0.1856 - val_accuracy: 0.8944 - val_loss: 0.4247 - learning_rate: 5.0000e-04
# Epoch 70/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.9538 - loss: 0.1672
# Epoch 70: val_loss did not improve from 0.36446
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - accuracy: 0.9536 - loss: 0.1676 - val_accuracy: 0.8778 - val_loss: 0.5639 - learning_rate: 5.0000e-04
# Epoch 71/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9609 - loss: 0.1154
# Epoch 71: val_loss did not improve from 0.36446
#
# [DEBUG] Epoch 71:
#   Train Loss: 0.1436, Train Acc: 0.9527
#   Val Loss: 0.5090, Val Acc: 0.8944
#   Learning Rate: 0.000500
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 148ms/step - accuracy: 0.9607 - loss: 0.1160 - val_accuracy: 0.8944 - val_loss: 0.5090 - learning_rate: 5.0000e-04
# Epoch 72/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9474 - loss: 0.1823
# Epoch 72: val_loss did not improve from 0.36446
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 143ms/step - accuracy: 0.9475 - loss: 0.1823 - val_accuracy: 0.8944 - val_loss: 0.4136 - learning_rate: 5.0000e-04
# Epoch 73/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9706 - loss: 0.1213
# Epoch 73: val_loss did not improve from 0.36446
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 148ms/step - accuracy: 0.9704 - loss: 0.1215 - val_accuracy: 0.8667 - val_loss: 0.4890 - learning_rate: 5.0000e-04
# Epoch 74/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9634 - loss: 0.1425
# Epoch 74: val_loss did not improve from 0.36446
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 145ms/step - accuracy: 0.9637 - loss: 0.1416 - val_accuracy: 0.9056 - val_loss: 0.4368 - learning_rate: 5.0000e-04
# Epoch 75/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.9722 - loss: 0.1062
# Epoch 75: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 75: val_loss did not improve from 0.36446
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 146ms/step - accuracy: 0.9723 - loss: 0.1059 - val_accuracy: 0.8778 - val_loss: 0.4501 - learning_rate: 5.0000e-04
# Epoch 76/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.9817 - loss: 0.0814
# Epoch 76: val_loss improved from 0.36446 to 0.35989, saving model to best_optimized_model.keras
#
# [DEBUG] Epoch 76:
#   Train Loss: 0.0891, Train Acc: 0.9777
#   Val Loss: 0.3599, Val Acc: 0.8944
#   Learning Rate: 0.000250
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 150ms/step - accuracy: 0.9816 - loss: 0.0816 - val_accuracy: 0.8944 - val_loss: 0.3599 - learning_rate: 2.5000e-04
# Epoch 77/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9784 - loss: 0.0742
# Epoch 77: val_loss did not improve from 0.35989
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 151ms/step - accuracy: 0.9783 - loss: 0.0745 - val_accuracy: 0.9111 - val_loss: 0.3949 - learning_rate: 2.5000e-04
# Epoch 78/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.9779 - loss: 0.0828
# Epoch 78: val_loss did not improve from 0.35989
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - accuracy: 0.9780 - loss: 0.0825 - val_accuracy: 0.9167 - val_loss: 0.3756 - learning_rate: 2.5000e-04
# Epoch 79/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9784 - loss: 0.0953
# Epoch 79: val_loss improved from 0.35989 to 0.35551, saving model to best_optimized_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 162ms/step - accuracy: 0.9786 - loss: 0.0951 - val_accuracy: 0.8944 - val_loss: 0.3555 - learning_rate: 2.5000e-04
# Epoch 80/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.9902 - loss: 0.0625
# Epoch 80: val_loss did not improve from 0.35551
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - accuracy: 0.9900 - loss: 0.0629 - val_accuracy: 0.9111 - val_loss: 0.3705 - learning_rate: 2.5000e-04
# Epoch 81/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9984 - loss: 0.0432
# Epoch 81: val_loss did not improve from 0.35551
#
# [DEBUG] Epoch 81:
#   Train Loss: 0.0529, Train Acc: 0.9944
#   Val Loss: 0.4175, Val Acc: 0.9000
#   Learning Rate: 0.000250
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 155ms/step - accuracy: 0.9983 - loss: 0.0434 - val_accuracy: 0.9000 - val_loss: 0.4175 - learning_rate: 2.5000e-04
# Epoch 82/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.9909 - loss: 0.0504
# Epoch 82: val_loss did not improve from 0.35551
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - accuracy: 0.9909 - loss: 0.0507 - val_accuracy: 0.9111 - val_loss: 0.3993 - learning_rate: 2.5000e-04
# Epoch 83/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9897 - loss: 0.0648
# Epoch 83: val_loss did not improve from 0.35551
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 152ms/step - accuracy: 0.9896 - loss: 0.0648 - val_accuracy: 0.9056 - val_loss: 0.3729 - learning_rate: 2.5000e-04
# Epoch 84/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.9935 - loss: 0.0383
# Epoch 84: val_loss improved from 0.35551 to 0.34927, saving model to best_optimized_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 155ms/step - accuracy: 0.9933 - loss: 0.0387 - val_accuracy: 0.9000 - val_loss: 0.3493 - learning_rate: 2.5000e-04
# Epoch 85/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9870 - loss: 0.0601
# Epoch 85: val_loss improved from 0.34927 to 0.33682, saving model to best_optimized_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 152ms/step - accuracy: 0.9870 - loss: 0.0601 - val_accuracy: 0.9222 - val_loss: 0.3368 - learning_rate: 2.5000e-04
# Epoch 86/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9937 - loss: 0.0724
# Epoch 86: val_loss improved from 0.33682 to 0.30869, saving model to best_optimized_model.keras
#
# [DEBUG] Epoch 86:
#   Train Loss: 0.0758, Train Acc: 0.9875
#   Val Loss: 0.3087, Val Acc: 0.9222
#   Learning Rate: 0.000250
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 171ms/step - accuracy: 0.9936 - loss: 0.0725 - val_accuracy: 0.9222 - val_loss: 0.3087 - learning_rate: 2.5000e-04
# Epoch 87/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.9947 - loss: 0.0400
# Epoch 87: val_loss did not improve from 0.30869
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - accuracy: 0.9947 - loss: 0.0400 - val_accuracy: 0.9389 - val_loss: 0.3174 - learning_rate: 2.5000e-04
# Epoch 88/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9862 - loss: 0.0606
# Epoch 88: val_loss improved from 0.30869 to 0.27147, saving model to best_optimized_model.keras
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 162ms/step - accuracy: 0.9861 - loss: 0.0609 - val_accuracy: 0.9167 - val_loss: 0.2715 - learning_rate: 2.5000e-04
# Epoch 89/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.9897 - loss: 0.0515
# Epoch 89: val_loss did not improve from 0.27147
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - accuracy: 0.9896 - loss: 0.0520 - val_accuracy: 0.9111 - val_loss: 0.2905 - learning_rate: 2.5000e-04
# Epoch 90/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.9765 - loss: 0.0787
# Epoch 90: val_loss did not improve from 0.27147
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 153ms/step - accuracy: 0.9765 - loss: 0.0786 - val_accuracy: 0.9389 - val_loss: 0.3123 - learning_rate: 2.5000e-04
# Epoch 91/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.9640 - loss: 0.1247
# Epoch 91: val_loss did not improve from 0.27147
#
# [DEBUG] Epoch 91:
#   Train Loss: 0.0967, Train Acc: 0.9750
#   Val Loss: 0.3186, Val Acc: 0.9389
#   Learning Rate: 0.000250
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - accuracy: 0.9643 - loss: 0.1241 - val_accuracy: 0.9389 - val_loss: 0.3186 - learning_rate: 2.5000e-04
# Epoch 92/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.9884 - loss: 0.0615
# Epoch 92: val_loss did not improve from 0.27147
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 153ms/step - accuracy: 0.9884 - loss: 0.0615 - val_accuracy: 0.9222 - val_loss: 0.4094 - learning_rate: 2.5000e-04
# Epoch 93/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.9867 - loss: 0.0612
# Epoch 93: val_loss did not improve from 0.27147
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 141ms/step - accuracy: 0.9867 - loss: 0.0614 - val_accuracy: 0.9167 - val_loss: 0.3256 - learning_rate: 2.5000e-04
# Epoch 94/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9924 - loss: 0.0493
# Epoch 94: val_loss did not improve from 0.27147
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 154ms/step - accuracy: 0.9924 - loss: 0.0494 - val_accuracy: 0.9222 - val_loss: 0.3214 - learning_rate: 2.5000e-04
# Epoch 95/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.9765 - loss: 0.0741
# Epoch 95: val_loss did not improve from 0.27147
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - accuracy: 0.9765 - loss: 0.0742 - val_accuracy: 0.9333 - val_loss: 0.3183 - learning_rate: 2.5000e-04
# Epoch 96/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9856 - loss: 0.0637
# Epoch 96: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 96: val_loss did not improve from 0.27147
#
# [DEBUG] Epoch 96:
#   Train Loss: 0.0599, Train Acc: 0.9875
#   Val Loss: 0.3167, Val Acc: 0.9167
#   Learning Rate: 0.000125
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 152ms/step - accuracy: 0.9857 - loss: 0.0636 - val_accuracy: 0.9167 - val_loss: 0.3167 - learning_rate: 2.5000e-04
# Epoch 97/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.9843 - loss: 0.0468
# Epoch 97: val_loss did not improve from 0.27147
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - accuracy: 0.9844 - loss: 0.0468 - val_accuracy: 0.9278 - val_loss: 0.3300 - learning_rate: 1.2500e-04
# Epoch 98/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.9908 - loss: 0.0517
# Epoch 98: val_loss did not improve from 0.27147
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 152ms/step - accuracy: 0.9906 - loss: 0.0519 - val_accuracy: 0.9167 - val_loss: 0.3800 - learning_rate: 1.2500e-04
# Epoch 99/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9859 - loss: 0.0686
# Epoch 99: val_loss did not improve from 0.27147
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 150ms/step - accuracy: 0.9860 - loss: 0.0685 - val_accuracy: 0.9389 - val_loss: 0.3327 - learning_rate: 1.2500e-04
# Epoch 100/100
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.9840 - loss: 0.0694
# Epoch 100: val_loss did not improve from 0.27147
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - accuracy: 0.9840 - loss: 0.0694 - val_accuracy: 0.9222 - val_loss: 0.3577 - learning_rate: 1.2500e-04
# Restoring model weights from the end of the best epoch: 88.
#
# Generating training plots...
# Evaluating model...
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 119ms/step
#
# ======================================================================
# TEST ACCURACY: 0.9167 (91.67%)
# ======================================================================
#
# Classification Report:
#                          precision    recall  f1-score   support
#
#          Moon_jellyfish       1.00      1.00      1.00        30
#        barrel_jellyfish       0.90      0.87      0.88        30
#          blue_jellyfish       0.91      1.00      0.95        30
#       compass_jellyfish       0.78      0.93      0.85        30
#    lions_mane_jellyfish       0.96      0.90      0.93        30
# mauve_stinger_jellyfish       1.00      0.80      0.89        30
#
#                accuracy                           0.92       180
#               macro avg       0.92      0.92      0.92       180
#            weighted avg       0.92      0.92      0.92       180
#
#
# Per-Class Accuracy:
#   Moon_jellyfish: 1.0000 (100.00%)
#   barrel_jellyfish: 0.8667 (86.67%)
#   blue_jellyfish: 1.0000 (100.00%)
#   compass_jellyfish: 0.9333 (93.33%)
#   lions_mane_jellyfish: 0.9000 (90.00%)
#   mauve_stinger_jellyfish: 0.8000 (80.00%)
# ✓ Metrics saved to 'training_metrics.csv'
#
# ======================================================================
# Training completed successfully!
# ======================================================================
