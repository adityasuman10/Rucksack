# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
import seaborn as sns
from PIL import Image
import random
import keras
from keras import layers, models, optimizers, callbacks

# Set seeds for reproducibility
random.seed(42)
np.random.seed(42)
keras.utils.set_random_seed(42)

# ============================================================================
# CONFIGURATION - Tune these for your needs
# ============================================================================
IMAGE_SIZE = 128          # Reduced from 224 (2x faster, still captures detail)
NUM_CLASSES = 6
BATCH_SIZE = 8            # Increased from 4 (faster training)
LEARNING_RATE = 5e-4
WEIGHT_DECAY = 1e-4
EPOCHS = 150
DATASET_PATH = r"/content/drive/MyDrive/concave_jellyfish/concave"  # Change to your path

# Model complexity settings
USE_LIGHTWEIGHT = True    # Set False for more accuracy, True for speed
MULTISCALE_STAGES = [1]   # Apply multi-scale only to Stage 1 (fastest)
                          # Use [1, 2] for more accuracy, [1, 2, 3] for maximum

# ============================================================================
# DATA LOADING
# ============================================================================
def create_augmentation_layer():
    """Optimized augmentation for ISAR"""
    return keras.Sequential([
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.08),       # Reduced from 0.15
        layers.RandomZoom(0.12),           # Reduced from 0.15
        layers.RandomContrast(0.15),
    ])

# ============================================================================
# OPTIMIZED MULTI-SCALE CONV (Reduced from 7 to 4 branches)
# ============================================================================
def lightweight_multiscale_conv(x, channels, stride=1):
    """
    Optimized multi-scale for ISAR with only 4 essential branches:
    - 3x3: Standard local features
    - 5x5: Medium-scale scattering points
    - Anisotropic (1x7, 7x1): Linear features (ship edges, aircraft wings)
    """
    # Branch 1: 3x3 - Fast, local features
    branch_3x3 = layers.DepthwiseConv2D(3, strides=stride, padding='same', use_bias=False)(x)
    branch_3x3 = layers.BatchNormalization()(branch_3x3)

    # Branch 2: 5x5 - Medium-scale features
    branch_5x5 = layers.DepthwiseConv2D(5, strides=stride, padding='same', use_bias=False)(x)
    branch_5x5 = layers.BatchNormalization()(branch_5x5)

    # Branch 3: Anisotropic horizontal (1x7) - Horizontal edges/features
    branch_h = layers.DepthwiseConv2D((1, 7), strides=stride, padding='same', use_bias=False)(x)
    branch_h = layers.BatchNormalization()(branch_h)

    # Branch 4: Anisotropic vertical (7x1) - Vertical edges/features
    branch_v = layers.DepthwiseConv2D((7, 1), strides=stride, padding='same', use_bias=False)(x)
    branch_v = layers.BatchNormalization()(branch_v)

    # Concatenate all branches
    multi_scale = layers.Concatenate(axis=-1)([branch_3x3, branch_5x5, branch_h, branch_v])

    # Fuse features with 1x1 conv
    multi_scale = layers.Conv2D(channels, 1, padding='same', use_bias=False)(multi_scale)
    multi_scale = layers.BatchNormalization()(multi_scale)
    multi_scale = layers.Activation('gelu')(multi_scale)

    return multi_scale

# ============================================================================
# ECA BLOCK (Efficient Channel Attention)
# ============================================================================
def eca_block(x, channels, k_size=3):
    """Efficient Channel Attention - 3x faster than SE block"""
    eca = layers.GlobalAveragePooling2D()(x)
    eca = layers.Reshape((channels, 1))(eca)
    eca = layers.Conv1D(1, kernel_size=k_size, padding='same', use_bias=False)(eca)
    eca = layers.Reshape((1, 1, channels))(eca)
    eca = layers.Activation('sigmoid')(eca)
    return layers.Multiply()([x, eca])

# ============================================================================
# OPTIMIZED MBCONV BLOCK
# ============================================================================
def optimized_mbconv_block(x, in_channels, out_channels, expansion_factor=4,
                          stride=1, use_multiscale=False):
    """
    Optimized MBConv with optional multi-scale
    use_multiscale=True: Better accuracy, slower
    use_multiscale=False: Standard conv, faster
    """
    input_tensor = x
    expanded_channels = in_channels * expansion_factor

    # Expansion phase
    if expansion_factor != 1:
        x = layers.Conv2D(expanded_channels, 1, padding='same', use_bias=False)(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation('gelu')(x)

    # Depthwise convolution - Choose between multi-scale or standard
    if use_multiscale:
        x = lightweight_multiscale_conv(x, expanded_channels, stride)
    else:
        x = layers.DepthwiseConv2D(3, strides=stride, padding='same', use_bias=False)(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation('gelu')(x)

    # ECA attention
    x = eca_block(x, expanded_channels)

    # Projection phase
    x = layers.Conv2D(out_channels, 1, padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)

    # Residual connection
    if stride == 1 and in_channels == out_channels:
        x = layers.Add()([input_tensor, x])

    return x

# ============================================================================
# LIGHTWEIGHT TRANSFORMER BLOCK
# ============================================================================
def lightweight_transformer_block(x, in_channels, out_channels, stride=1):
    """Simplified transformer for speed"""
    input_tensor = x

    # Handle channel changes
    if in_channels != out_channels:
        input_tensor = layers.Conv2D(out_channels, 1, use_bias=False)(input_tensor)
        input_tensor = layers.BatchNormalization()(input_tensor)
        x = layers.Conv2D(out_channels, 1, use_bias=False)(x)
        x = layers.BatchNormalization()(x)

    # Handle spatial changes
    if stride > 1:
        x = layers.MaxPooling2D(stride)(x)
        input_tensor = layers.MaxPooling2D(stride)(input_tensor)

    # Lightweight attention (single conv path)
    attn = layers.LayerNormalization()(x)
    attn = layers.Conv2D(out_channels, 3, padding='same')(attn)
    attn = layers.Activation('gelu')(attn)
    attn = layers.Dropout(0.1)(attn)
    x = layers.Add()([x, attn])

    # Lightweight FFN
    ff = layers.LayerNormalization()(x)
    ff = layers.Conv2D(out_channels * 2, 1)(ff)
    ff = layers.Activation('gelu')(ff)
    ff = layers.Conv2D(out_channels, 1)(ff)
    ff = layers.Dropout(0.1)(ff)
    x = layers.Add()([x, ff])

    # Final residual
    x = layers.Add()([input_tensor, x])

    return x

# ============================================================================
# MODEL CREATION
# ============================================================================
def create_optimized_coatnet(num_classes, image_size, use_lightweight=True):
    """
    Optimized CoAtNet for ISAR

    Parameters:
    - use_lightweight: True = ~4M params, False = ~6M params
    """
    inputs = layers.Input(shape=(image_size, image_size, 3))

    # Stem - Lightweight start
    if use_lightweight:
        stem_channels = 32
    else:
        stem_channels = 48

    x = layers.Conv2D(stem_channels, 3, strides=2, padding='same', use_bias=False)(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('gelu')(x)



    # Stage 1: MBConv blocks (56x56 or 64x64)
    use_ms_s1 = 1 in MULTISCALE_STAGES
    x = optimized_mbconv_block(x, stem_channels, stem_channels,
                               expansion_factor=3, use_multiscale=use_ms_s1)

    # Stage 2: MBConv with stride (28x28 or 32x32)
    use_ms_s2 = 2 in MULTISCALE_STAGES
    x = optimized_mbconv_block(x, stem_channels, stem_channels * 2,
                               expansion_factor=3, stride=2, use_multiscale=use_ms_s2)

    # Stage 3: Transformer block (14x14 or 16x16)
    x = lightweight_transformer_block(x, stem_channels * 2, stem_channels * 4, stride=2)

    # Stage 4: Final transformer (7x7 or 8x8)
    x = lightweight_transformer_block(x, stem_channels * 4, stem_channels * 6, stride=2)

    # Classification head
    x = layers.LayerNormalization()(x)
    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dropout(0.3)(x)
    x = layers.Dense(num_classes * 2, activation='gelu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inputs, outputs)
    return model

# ============================================================================
# TRAINING FUNCTIONS
# ============================================================================
def train_model(model, train_data, val_data, class_names):
    """Train with optimized callbacks"""

    model.compile(
        optimizer=optimizers.AdamW(
            learning_rate=LEARNING_RATE,
            weight_decay=WEIGHT_DECAY
        ),
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
    )

    print("=" * 70)
    model.summary()
    print("=" * 70)

    # Callbacks
    early_stopping = callbacks.EarlyStopping(
        monitor='val_loss',
        patience=50,              # Reduced from 45 for faster stopping
        restore_best_weights=True,
        verbose=1
    )

    reduce_lr = callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=7,               # More aggressive LR reduction
        min_lr=1e-7,
        verbose=1
    )

    model_checkpoint = callbacks.ModelCheckpoint(
        'best_optimized_model.keras',
        monitor='val_loss',
        save_best_only=True,
        verbose=1
    )

    # Train
    history = model.fit(
        train_data,
        validation_data=val_data,
        epochs=EPOCHS,
        callbacks=[early_stopping, reduce_lr, model_checkpoint],
        verbose=1
    )

    return history

def plot_training_history(history):
    """Plot training metrics"""
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

    # Loss
    ax1.plot(history.history['loss'], label='Training Loss', linewidth=2)
    ax1.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
    ax1.set_title('Model Loss', fontsize=14, fontweight='bold')
    ax1.set_xlabel('Epoch', fontsize=12)
    ax1.set_ylabel('Loss', fontsize=12)
    ax1.legend(fontsize=11)
    ax1.grid(True, alpha=0.3)

    # Accuracy
    ax2.plot(history.history['accuracy'], label='Training Accuracy', linewidth=2)
    ax2.plot(history.history['val_accuracy'], label='Validation Accuracy', linewidth=2)
    ax2.set_title('Model Accuracy', fontsize=14, fontweight='bold')
    ax2.set_xlabel('Epoch', fontsize=12)
    ax2.set_ylabel('Accuracy', fontsize=12)
    ax2.legend(fontsize=11)
    ax2.grid(True, alpha=0.3)

    plt.tight_layout()
    plt.savefig('training_history.png', dpi=150)
    plt.show()

def evaluate_model(model, test_data, class_names):
    """Evaluate and create confusion matrix"""

    # Get predictions
    y_pred = model.predict(test_data, verbose=1)
    y_pred_classes = np.argmax(y_pred, axis=1)

    # Get true labels
    y_true = []
    for _, labels in test_data:
        y_true.extend(labels.numpy())
    y_true = np.array(y_true)

    # Metrics
    accuracy = accuracy_score(y_true, y_pred_classes)
    print("\n" + "=" * 70)
    print(f"TEST ACCURACY: {accuracy:.4f} ({accuracy*100:.2f}%)")
    print("=" * 70)
    print("\nClassification Report:")
    print(classification_report(y_true, y_pred_classes, target_names=class_names))

    # Confusion matrix
    cm = confusion_matrix(y_true, y_pred_classes)

    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names, yticklabels=class_names,
                cbar_kws={'label': 'Count'})
    plt.title('Confusion Matrix', fontsize=16, fontweight='bold', pad=20)
    plt.xlabel('Predicted Label', fontsize=12)
    plt.ylabel('True Label', fontsize=12)
    plt.tight_layout()
    plt.savefig('confusion_matrix.png', dpi=150)
    plt.show()

    return accuracy, cm

# ============================================================================
# MAIN PIPELINE
# ============================================================================
def main():
    """Main training pipeline"""
    print("\n" + "=" * 70)
    print("OPTIMIZED ISAR CoAtNet - Fast & Accurate")
    print("=" * 70)
    print(f"Configuration:")
    print(f"  Image Size: {IMAGE_SIZE}x{IMAGE_SIZE}")
    print(f"  Batch Size: {BATCH_SIZE}")
    print(f"  Lightweight Mode: {USE_LIGHTWEIGHT}")
    print(f"  Multi-scale Stages: {MULTISCALE_STAGES}")
    print("=" * 70 + "\n")

    # Check dataset path
    if not os.path.exists(DATASET_PATH):
        print(f"❌ Dataset path {DATASET_PATH} does not exist!")
        print("Please update DATASET_PATH in the configuration section.")
        return

    # Load data
    try:
        print("Loading training data...")
        train_dataset = keras.utils.image_dataset_from_directory(
            DATASET_PATH,
            validation_split=0.2,
            subset="training",
            seed=42,
            image_size=(IMAGE_SIZE, IMAGE_SIZE),
            batch_size=BATCH_SIZE,
            label_mode='int'
        )

        print("Loading validation data...")
        val_dataset = keras.utils.image_dataset_from_directory(
            DATASET_PATH,
            validation_split=0.2,
            subset="validation",
            seed=42,
            image_size=(IMAGE_SIZE, IMAGE_SIZE),
            batch_size=BATCH_SIZE,
            label_mode='int'
        )

        class_names = train_dataset.class_names
        num_classes = len(class_names)

        print(f"\n✓ Found {num_classes} classes: {class_names}")

        # Count samples
        train_samples = sum(1 for _ in train_dataset.unbatch())
        val_samples = sum(1 for _ in val_dataset.unbatch())
        print(f"✓ Training samples: {train_samples}")
        print(f"✓ Validation samples: {val_samples}\n")

    except Exception as e:
        print(f"❌ Error loading dataset: {e}")
        return

    # Normalize and optimize
    normalization = layers.Rescaling(1./255)
    train_dataset = train_dataset.map(lambda x, y: (normalization(x), y))
    val_dataset = val_dataset.map(lambda x, y: (normalization(x), y))

    AUTOTUNE = -1
    train_dataset = train_dataset.cache().prefetch(buffer_size=AUTOTUNE)
    val_dataset = val_dataset.cache().prefetch(buffer_size=AUTOTUNE)

    # Create model
    print("Creating optimized model...\n")
    model = create_optimized_coatnet(num_classes, IMAGE_SIZE, USE_LIGHTWEIGHT)

    # Train
    print("Starting training...\n")
    history = train_model(model, train_dataset, val_dataset, class_names)

    # Plot results
    print("\nGenerating training plots...")
    plot_training_history(history)

    # Evaluate
    print("\nEvaluating model...")
    accuracy, cm = evaluate_model(model, val_dataset, class_names)

    # Save metrics
    metrics_df = pd.DataFrame({
        'epoch': range(len(history.history['loss'])),
        'train_loss': history.history['loss'],
        'val_loss': history.history['val_loss'],
        'train_accuracy': history.history['accuracy'],
        'val_accuracy': history.history['val_accuracy']
    })
    metrics_df.to_csv('training_metrics.csv', index=False)
    print("\n✓ Metrics saved to 'training_metrics.csv'")

    print("\n" + "=" * 70)
    print("Training completed successfully!")
    print("=" * 70)

if __name__ == "__main__":
    main()
# Out:
# ======================================================================
# OPTIMIZED ISAR CoAtNet - Fast & Accurate
# ======================================================================
# Configuration:
#   Image Size: 128x128
#   Batch Size: 8
#   Lightweight Mode: True
#   Multi-scale Stages: [1]
# ======================================================================
#
# Loading training data...
# Found 900 files belonging to 6 classes.
# Using 720 files for training.
# Loading validation data...
# Found 900 files belonging to 6 classes.
# Using 180 files for validation.
#
# ✓ Found 6 classes: ['Moon_jellyfish', 'barrel_jellyfish', 'blue_jellyfish', 'compass_jellyfish', 'lions_mane_jellyfish', 'mauve_stinger_jellyfish']
# ✓ Training samples: 720
# ✓ Validation samples: 180
#
# Creating optimized model...
#
# Starting training...
#
# ======================================================================
# Model: "functional_7"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_8       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_127 (Conv2D) │ (None, 64, 64,    │        864 │ input_layer_8[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_127[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_89       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_128 (Conv2D) │ (None, 64, 64,    │      3,072 │ activation_89[0]… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        384 │ conv2d_128[0][0]  │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_90       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_50 │ (None, 64, 64,    │        864 │ activation_90[0]… │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_51 │ (None, 64, 64,    │      2,400 │ activation_90[0]… │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_52 │ (None, 64, 64,    │        672 │ activation_90[0]… │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_53 │ (None, 64, 64,    │        672 │ activation_90[0]… │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        384 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        384 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        384 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        384 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_11      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Concatenate)       │ 384)              │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_129 (Conv2D) │ (None, 64, 64,    │     36,864 │ concatenate_11[0… │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        384 │ conv2d_129[0][0]  │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_91       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 96)        │          0 │ activation_91[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_42          │ (None, 96, 1)     │          0 │ global_average_p… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_17 (Conv1D)  │ (None, 96, 1)     │          3 │ reshape_42[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_43          │ (None, 1, 1, 96)  │          0 │ conv1d_17[0][0]   │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_92       │ (None, 1, 1, 96)  │          0 │ reshape_43[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_17         │ (None, 64, 64,    │          0 │ activation_91[0]… │
# │ (Multiply)          │ 96)               │            │ activation_92[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_130 (Conv2D) │ (None, 64, 64,    │      3,072 │ multiply_17[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_130[0][0]  │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_57 (Add)        │ (None, 64, 64,    │          0 │ activation_89[0]… │
# │                     │ 32)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_131 (Conv2D) │ (None, 64, 64,    │      3,072 │ add_57[0][0]      │
# │                     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        384 │ conv2d_131[0][0]  │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_93       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv2d_54 │ (None, 32, 32,    │        864 │ activation_93[0]… │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        384 │ depthwise_conv2d… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_94       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 96)        │          0 │ activation_94[0]… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_44          │ (None, 96, 1)     │          0 │ global_average_p… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_18 (Conv1D)  │ (None, 96, 1)     │          3 │ reshape_44[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_45          │ (None, 1, 1, 96)  │          0 │ conv1d_18[0][0]   │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_95       │ (None, 1, 1, 96)  │          0 │ reshape_45[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_18         │ (None, 32, 32,    │          0 │ activation_94[0]… │
# │ (Multiply)          │ 96)               │            │ activation_95[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_132 (Conv2D) │ (None, 32, 32,    │      6,144 │ multiply_18[0][0] │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_132[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_134 (Conv2D) │ (None, 32, 32,    │      8,192 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_134[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_28    │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 16, 16,    │        256 │ max_pooling2d_28… │
# │ (LayerNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_135 (Conv2D) │ (None, 16, 16,    │    147,584 │ layer_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_96       │ (None, 16, 16,    │          0 │ conv2d_135[0][0]  │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_54          │ (None, 16, 16,    │          0 │ activation_96[0]… │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_58 (Add)        │ (None, 16, 16,    │          0 │ max_pooling2d_28… │
# │                     │ 128)              │            │ dropout_54[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 16, 16,    │        256 │ add_58[0][0]      │
# │ (LayerNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_136 (Conv2D) │ (None, 16, 16,    │     33,024 │ layer_normalizat… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_97       │ (None, 16, 16,    │          0 │ conv2d_136[0][0]  │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_133 (Conv2D) │ (None, 32, 32,    │      8,192 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_137 (Conv2D) │ (None, 16, 16,    │     32,896 │ activation_97[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ conv2d_133[0][0]  │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_55          │ (None, 16, 16,    │          0 │ conv2d_137[0][0]  │
# │ (Dropout)           │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_29    │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_59 (Add)        │ (None, 16, 16,    │          0 │ add_58[0][0],     │
# │                     │ 128)              │            │ dropout_55[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_60 (Add)        │ (None, 16, 16,    │          0 │ max_pooling2d_29… │
# │                     │ 128)              │            │ add_59[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_139 (Conv2D) │ (None, 16, 16,    │     24,576 │ add_60[0][0]      │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        768 │ conv2d_139[0][0]  │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_30    │ (None, 8, 8, 192) │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 8, 8, 192) │        384 │ max_pooling2d_30… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_140 (Conv2D) │ (None, 8, 8, 192) │    331,968 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_98       │ (None, 8, 8, 192) │          0 │ conv2d_140[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_56          │ (None, 8, 8, 192) │          0 │ activation_98[0]… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_61 (Add)        │ (None, 8, 8, 192) │          0 │ max_pooling2d_30… │
# │                     │                   │            │ dropout_56[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 8, 8, 192) │        384 │ add_61[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_141 (Conv2D) │ (None, 8, 8, 384) │     74,112 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_99       │ (None, 8, 8, 384) │          0 │ conv2d_141[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_138 (Conv2D) │ (None, 16, 16,    │     24,576 │ add_60[0][0]      │
# │                     │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_142 (Conv2D) │ (None, 8, 8, 192) │     73,920 │ activation_99[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        768 │ conv2d_138[0][0]  │
# │ (BatchNormalizatio… │ 192)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_57          │ (None, 8, 8, 192) │          0 │ conv2d_142[0][0]  │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_31    │ (None, 8, 8, 192) │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_62 (Add)        │ (None, 8, 8, 192) │          0 │ add_61[0][0],     │
# │                     │                   │            │ dropout_57[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_63 (Add)        │ (None, 8, 8, 192) │          0 │ max_pooling2d_31… │
# │                     │                   │            │ add_62[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 8, 8, 192) │        384 │ add_63[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 192)       │          0 │ layer_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_58          │ (None, 192)       │          0 │ global_average_p… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_14 (Dense)    │ (None, 12)        │      2,316 │ dropout_58[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_59          │ (None, 12)        │          0 │ dense_14[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_15 (Dense)    │ (None, 6)         │         78 │ dropout_59[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 827,808 (3.16 MB)
#  Trainable params: 824,736 (3.15 MB)
#  Non-trainable params: 3,072 (12.00 KB)
# ======================================================================
# Epoch 1/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.1878 - loss: 1.9084
# Epoch 1: val_loss improved from inf to 1.79885, saving model to best_optimized_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 40s 119ms/step - accuracy: 0.1879 - loss: 1.9078 - val_accuracy: 0.1333 - val_loss: 1.7989 - learning_rate: 5.0000e-04
# Epoch 2/150
# 89/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.2656 - loss: 1.7403
# Epoch 2: val_loss improved from 1.79885 to 1.78596, saving model to best_optimized_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 16s 27ms/step - accuracy: 0.2659 - loss: 1.7394 - val_accuracy: 0.2111 - val_loss: 1.7860 - learning_rate: 5.0000e-04
# Epoch 3/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.2889 - loss: 1.6770
# Epoch 3: val_loss did not improve from 1.78596
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.2892 - loss: 1.6760 - val_accuracy: 0.1389 - val_loss: 1.7994 - learning_rate: 5.0000e-04
# Epoch 4/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.2928 - loss: 1.6427
# Epoch 4: val_loss improved from 1.78596 to 1.72667, saving model to best_optimized_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.2937 - loss: 1.6409 - val_accuracy: 0.3222 - val_loss: 1.7267 - learning_rate: 5.0000e-04
# Epoch 5/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.3364 - loss: 1.5491
# Epoch 5: val_loss improved from 1.72667 to 1.70593, saving model to best_optimized_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.3366 - loss: 1.5490 - val_accuracy: 0.2889 - val_loss: 1.7059 - learning_rate: 5.0000e-04
# Epoch 6/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.3738 - loss: 1.4919
# Epoch 6: val_loss improved from 1.70593 to 1.57016, saving model to best_optimized_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.3735 - loss: 1.4925 - val_accuracy: 0.3500 - val_loss: 1.5702 - learning_rate: 5.0000e-04
# Epoch 7/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.3787 - loss: 1.4648
# Epoch 7: val_loss improved from 1.57016 to 1.44359, saving model to best_optimized_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.3796 - loss: 1.4649 - val_accuracy: 0.4278 - val_loss: 1.4436 - learning_rate: 5.0000e-04
# Epoch 8/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4089 - loss: 1.4083
# Epoch 8: val_loss improved from 1.44359 to 1.40178, saving model to best_optimized_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - accuracy: 0.4087 - loss: 1.4092 - val_accuracy: 0.4667 - val_loss: 1.4018 - learning_rate: 5.0000e-04
# Epoch 9/150
# 89/90 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.4722 - loss: 1.2638
# Epoch 9: val_loss improved from 1.40178 to 1.28226, saving model to best_optimized_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 32ms/step - accuracy: 0.4727 - loss: 1.2645 - val_accuracy: 0.5333 - val_loss: 1.2823 - learning_rate: 5.0000e-04
# Epoch 10/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4865 - loss: 1.2622
# Epoch 10: val_loss did not improve from 1.28226
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.4864 - loss: 1.2625 - val_accuracy: 0.4444 - val_loss: 1.3227 - learning_rate: 5.0000e-04
# Epoch 11/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5064 - loss: 1.2211
# Epoch 11: val_loss did not improve from 1.28226
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.5074 - loss: 1.2201 - val_accuracy: 0.3833 - val_loss: 1.4672 - learning_rate: 5.0000e-04
# Epoch 12/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4871 - loss: 1.2076
# Epoch 12: val_loss improved from 1.28226 to 1.22996, saving model to best_optimized_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.4890 - loss: 1.2056 - val_accuracy: 0.4889 - val_loss: 1.2300 - learning_rate: 5.0000e-04
# Epoch 13/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5053 - loss: 1.1651
# Epoch 13: val_loss improved from 1.22996 to 1.13437, saving model to best_optimized_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.5064 - loss: 1.1642 - val_accuracy: 0.5889 - val_loss: 1.1344 - learning_rate: 5.0000e-04
# Epoch 14/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.5782 - loss: 1.0207
# Epoch 14: val_loss improved from 1.13437 to 1.07849, saving model to best_optimized_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.5788 - loss: 1.0200 - val_accuracy: 0.5556 - val_loss: 1.0785 - learning_rate: 5.0000e-04
# Epoch 15/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.5970 - loss: 0.9858
# Epoch 15: val_loss did not improve from 1.07849
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.5980 - loss: 0.9861 - val_accuracy: 0.5444 - val_loss: 1.1727 - learning_rate: 5.0000e-04
# Epoch 16/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6011 - loss: 0.9313
# Epoch 16: val_loss improved from 1.07849 to 1.00520, saving model to best_optimized_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.6027 - loss: 0.9297 - val_accuracy: 0.6056 - val_loss: 1.0052 - learning_rate: 5.0000e-04
# Epoch 17/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6360 - loss: 0.8606
# Epoch 17: val_loss improved from 1.00520 to 0.96390, saving model to best_optimized_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.6371 - loss: 0.8596 - val_accuracy: 0.6333 - val_loss: 0.9639 - learning_rate: 5.0000e-04
# Epoch 18/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6739 - loss: 0.7577
# Epoch 18: val_loss did not improve from 0.96390
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.6750 - loss: 0.7572 - val_accuracy: 0.5722 - val_loss: 0.9883 - learning_rate: 5.0000e-04
# Epoch 19/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.6940 - loss: 0.7382
# Epoch 19: val_loss improved from 0.96390 to 0.85640, saving model to best_optimized_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.6943 - loss: 0.7384 - val_accuracy: 0.6833 - val_loss: 0.8564 - learning_rate: 5.0000e-04
# Epoch 20/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7460 - loss: 0.6900
# Epoch 20: val_loss did not improve from 0.85640
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.7460 - loss: 0.6906 - val_accuracy: 0.6833 - val_loss: 0.9322 - learning_rate: 5.0000e-04
# Epoch 21/150
# 89/90 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7751 - loss: 0.6264
# Epoch 21: val_loss did not improve from 0.85640
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.7752 - loss: 0.6266 - val_accuracy: 0.6389 - val_loss: 0.9702 - learning_rate: 5.0000e-04
# Epoch 22/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7545 - loss: 0.6398
# Epoch 22: val_loss improved from 0.85640 to 0.84187, saving model to best_optimized_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.7556 - loss: 0.6371 - val_accuracy: 0.7000 - val_loss: 0.8419 - learning_rate: 5.0000e-04
# Epoch 23/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7813 - loss: 0.5735
# Epoch 23: val_loss did not improve from 0.84187
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.7812 - loss: 0.5733 - val_accuracy: 0.6611 - val_loss: 0.8719 - learning_rate: 5.0000e-04
# Epoch 24/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8546 - loss: 0.4639
# Epoch 24: val_loss did not improve from 0.84187
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.8542 - loss: 0.4636 - val_accuracy: 0.7167 - val_loss: 0.8987 - learning_rate: 5.0000e-04
# Epoch 25/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8223 - loss: 0.4990
# Epoch 25: val_loss improved from 0.84187 to 0.82881, saving model to best_optimized_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.8223 - loss: 0.4984 - val_accuracy: 0.6944 - val_loss: 0.8288 - learning_rate: 5.0000e-04
# Epoch 26/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8726 - loss: 0.4312
# Epoch 26: val_loss did not improve from 0.82881
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.8724 - loss: 0.4309 - val_accuracy: 0.7000 - val_loss: 0.9646 - learning_rate: 5.0000e-04
# Epoch 27/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8451 - loss: 0.4659
# Epoch 27: val_loss improved from 0.82881 to 0.80361, saving model to best_optimized_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - accuracy: 0.8451 - loss: 0.4656 - val_accuracy: 0.7056 - val_loss: 0.8036 - learning_rate: 5.0000e-04
# Epoch 28/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8849 - loss: 0.3331
# Epoch 28: val_loss did not improve from 0.80361
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.8847 - loss: 0.3341 - val_accuracy: 0.6556 - val_loss: 1.0223 - learning_rate: 5.0000e-04
# Epoch 29/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8186 - loss: 0.5142
# Epoch 29: val_loss did not improve from 0.80361
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.8191 - loss: 0.5133 - val_accuracy: 0.6722 - val_loss: 1.0084 - learning_rate: 5.0000e-04
# Epoch 30/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9095 - loss: 0.2663
# Epoch 30: val_loss improved from 0.80361 to 0.75998, saving model to best_optimized_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9092 - loss: 0.2670 - val_accuracy: 0.7722 - val_loss: 0.7600 - learning_rate: 5.0000e-04
# Epoch 31/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8608 - loss: 0.3441
# Epoch 31: val_loss did not improve from 0.75998
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.8607 - loss: 0.3446 - val_accuracy: 0.7611 - val_loss: 0.8034 - learning_rate: 5.0000e-04
# Epoch 32/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9094 - loss: 0.2550
# Epoch 32: val_loss did not improve from 0.75998
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9095 - loss: 0.2549 - val_accuracy: 0.7333 - val_loss: 0.8007 - learning_rate: 5.0000e-04
# Epoch 33/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9181 - loss: 0.2247
# Epoch 33: val_loss did not improve from 0.75998
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9184 - loss: 0.2245 - val_accuracy: 0.6944 - val_loss: 1.0263 - learning_rate: 5.0000e-04
# Epoch 34/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9410 - loss: 0.2212
# Epoch 34: val_loss did not improve from 0.75998
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9402 - loss: 0.2219 - val_accuracy: 0.6944 - val_loss: 1.3527 - learning_rate: 5.0000e-04
# Epoch 35/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8921 - loss: 0.2908
# Epoch 35: val_loss did not improve from 0.75998
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.8922 - loss: 0.2908 - val_accuracy: 0.6667 - val_loss: 1.1834 - learning_rate: 5.0000e-04
# Epoch 36/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9193 - loss: 0.2718
# Epoch 36: val_loss did not improve from 0.75998
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9191 - loss: 0.2717 - val_accuracy: 0.6944 - val_loss: 0.9417 - learning_rate: 5.0000e-04
# Epoch 37/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8874 - loss: 0.2738
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 37: val_loss did not improve from 0.75998
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.8877 - loss: 0.2732 - val_accuracy: 0.7444 - val_loss: 0.9490 - learning_rate: 5.0000e-04
# Epoch 38/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9253 - loss: 0.2478
# Epoch 38: val_loss improved from 0.75998 to 0.69037, saving model to best_optimized_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.9255 - loss: 0.2473 - val_accuracy: 0.8000 - val_loss: 0.6904 - learning_rate: 2.5000e-04
# Epoch 39/150
# 89/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9229 - loss: 0.2035
# Epoch 39: val_loss did not improve from 0.69037
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 5s 23ms/step - accuracy: 0.9232 - loss: 0.2028 - val_accuracy: 0.7833 - val_loss: 0.8187 - learning_rate: 2.5000e-04
# Epoch 40/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9418 - loss: 0.1701
# Epoch 40: val_loss improved from 0.69037 to 0.62511, saving model to best_optimized_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9423 - loss: 0.1697 - val_accuracy: 0.8222 - val_loss: 0.6251 - learning_rate: 2.5000e-04
# Epoch 41/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9384 - loss: 0.1683
# Epoch 41: val_loss did not improve from 0.62511
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9382 - loss: 0.1688 - val_accuracy: 0.7556 - val_loss: 0.9378 - learning_rate: 2.5000e-04
# Epoch 42/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9457 - loss: 0.1491
# Epoch 42: val_loss did not improve from 0.62511
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9460 - loss: 0.1484 - val_accuracy: 0.8056 - val_loss: 0.6284 - learning_rate: 2.5000e-04
# Epoch 43/150
# 89/90 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9383 - loss: 0.1845
# Epoch 43: val_loss improved from 0.62511 to 0.56474, saving model to best_optimized_model.keras
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.9384 - loss: 0.1841 - val_accuracy: 0.8500 - val_loss: 0.5647 - learning_rate: 2.5000e-04
# Epoch 44/150
# 89/90 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9548 - loss: 0.1533
# Epoch 44: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.9547 - loss: 0.1532 - val_accuracy: 0.8278 - val_loss: 0.6703 - learning_rate: 2.5000e-04
# Epoch 45/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9539 - loss: 0.1383
# Epoch 45: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9533 - loss: 0.1387 - val_accuracy: 0.8000 - val_loss: 0.7685 - learning_rate: 2.5000e-04
# Epoch 46/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9473 - loss: 0.1622
# Epoch 46: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9472 - loss: 0.1619 - val_accuracy: 0.8111 - val_loss: 0.6674 - learning_rate: 2.5000e-04
# Epoch 47/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9311 - loss: 0.1580
# Epoch 47: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9313 - loss: 0.1575 - val_accuracy: 0.8333 - val_loss: 0.7192 - learning_rate: 2.5000e-04
# Epoch 48/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9164 - loss: 0.1665
# Epoch 48: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9166 - loss: 0.1663 - val_accuracy: 0.8000 - val_loss: 0.7862 - learning_rate: 2.5000e-04
# Epoch 49/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9381 - loss: 0.1629
# Epoch 49: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9381 - loss: 0.1628 - val_accuracy: 0.8333 - val_loss: 0.7526 - learning_rate: 2.5000e-04
# Epoch 50/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9191 - loss: 0.1730
# Epoch 50: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 50: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9194 - loss: 0.1727 - val_accuracy: 0.8278 - val_loss: 0.6911 - learning_rate: 2.5000e-04
# Epoch 51/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9357 - loss: 0.1590
# Epoch 51: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9357 - loss: 0.1589 - val_accuracy: 0.8333 - val_loss: 0.6402 - learning_rate: 1.2500e-04
# Epoch 52/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9687 - loss: 0.1149
# Epoch 52: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9682 - loss: 0.1152 - val_accuracy: 0.8500 - val_loss: 0.6465 - learning_rate: 1.2500e-04
# Epoch 53/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9590 - loss: 0.1428
# Epoch 53: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9590 - loss: 0.1427 - val_accuracy: 0.8444 - val_loss: 0.6842 - learning_rate: 1.2500e-04
# Epoch 54/150
# 89/90 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9518 - loss: 0.1383
# Epoch 54: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9518 - loss: 0.1380 - val_accuracy: 0.8333 - val_loss: 0.7297 - learning_rate: 1.2500e-04
# Epoch 55/150
# 89/90 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9669 - loss: 0.1116
# Epoch 55: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9668 - loss: 0.1116 - val_accuracy: 0.8278 - val_loss: 0.6985 - learning_rate: 1.2500e-04
# Epoch 56/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9332 - loss: 0.1541
# Epoch 56: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9334 - loss: 0.1537 - val_accuracy: 0.8167 - val_loss: 0.6960 - learning_rate: 1.2500e-04
# Epoch 57/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9499 - loss: 0.1305
# Epoch 57: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 57: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9502 - loss: 0.1299 - val_accuracy: 0.8111 - val_loss: 0.7534 - learning_rate: 1.2500e-04
# Epoch 58/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9509 - loss: 0.1214
# Epoch 58: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9508 - loss: 0.1215 - val_accuracy: 0.8167 - val_loss: 0.7476 - learning_rate: 6.2500e-05
# Epoch 59/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9666 - loss: 0.0955
# Epoch 59: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9661 - loss: 0.0962 - val_accuracy: 0.8167 - val_loss: 0.7289 - learning_rate: 6.2500e-05
# Epoch 60/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9743 - loss: 0.0937
# Epoch 60: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9742 - loss: 0.0938 - val_accuracy: 0.8278 - val_loss: 0.7064 - learning_rate: 6.2500e-05
# Epoch 61/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9386 - loss: 0.1653
# Epoch 61: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9387 - loss: 0.1650 - val_accuracy: 0.8333 - val_loss: 0.6756 - learning_rate: 6.2500e-05
# Epoch 62/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9751 - loss: 0.0894
# Epoch 62: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9747 - loss: 0.0899 - val_accuracy: 0.8222 - val_loss: 0.6554 - learning_rate: 6.2500e-05
# Epoch 63/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9597 - loss: 0.1200
# Epoch 63: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9598 - loss: 0.1198 - val_accuracy: 0.8222 - val_loss: 0.6514 - learning_rate: 6.2500e-05
# Epoch 64/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9708 - loss: 0.0800
# Epoch 64: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 64: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9704 - loss: 0.0805 - val_accuracy: 0.8278 - val_loss: 0.6653 - learning_rate: 6.2500e-05
# Epoch 65/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9483 - loss: 0.1153
# Epoch 65: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9487 - loss: 0.1150 - val_accuracy: 0.8333 - val_loss: 0.6370 - learning_rate: 3.1250e-05
# Epoch 66/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9470 - loss: 0.1491
# Epoch 66: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9474 - loss: 0.1480 - val_accuracy: 0.8333 - val_loss: 0.6243 - learning_rate: 3.1250e-05
# Epoch 67/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9752 - loss: 0.1044
# Epoch 67: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.9752 - loss: 0.1044 - val_accuracy: 0.8333 - val_loss: 0.6409 - learning_rate: 3.1250e-05
# Epoch 68/150
# 89/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9579 - loss: 0.1134
# Epoch 68: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.9579 - loss: 0.1135 - val_accuracy: 0.8444 - val_loss: 0.6254 - learning_rate: 3.1250e-05
# Epoch 69/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9286 - loss: 0.1476
# Epoch 69: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9291 - loss: 0.1474 - val_accuracy: 0.8333 - val_loss: 0.6371 - learning_rate: 3.1250e-05
# Epoch 70/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9576 - loss: 0.1320
# Epoch 70: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9575 - loss: 0.1315 - val_accuracy: 0.8389 - val_loss: 0.6359 - learning_rate: 3.1250e-05
# Epoch 71/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9728 - loss: 0.1063
# Epoch 71: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 71: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9726 - loss: 0.1066 - val_accuracy: 0.8444 - val_loss: 0.6404 - learning_rate: 3.1250e-05
# Epoch 72/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9576 - loss: 0.1216
# Epoch 72: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9575 - loss: 0.1216 - val_accuracy: 0.8389 - val_loss: 0.6588 - learning_rate: 1.5625e-05
# Epoch 73/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9514 - loss: 0.1183
# Epoch 73: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9514 - loss: 0.1182 - val_accuracy: 0.8389 - val_loss: 0.6436 - learning_rate: 1.5625e-05
# Epoch 74/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9617 - loss: 0.1430
# Epoch 74: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9616 - loss: 0.1424 - val_accuracy: 0.8389 - val_loss: 0.6416 - learning_rate: 1.5625e-05
# Epoch 75/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9437 - loss: 0.1255
# Epoch 75: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9439 - loss: 0.1256 - val_accuracy: 0.8333 - val_loss: 0.6540 - learning_rate: 1.5625e-05
# Epoch 76/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9637 - loss: 0.1142
# Epoch 76: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9637 - loss: 0.1140 - val_accuracy: 0.8278 - val_loss: 0.6614 - learning_rate: 1.5625e-05
# Epoch 77/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9682 - loss: 0.1240
# Epoch 77: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9680 - loss: 0.1236 - val_accuracy: 0.8278 - val_loss: 0.6420 - learning_rate: 1.5625e-05
# Epoch 78/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9567 - loss: 0.1170
# Epoch 78: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 78: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9566 - loss: 0.1170 - val_accuracy: 0.8333 - val_loss: 0.6565 - learning_rate: 1.5625e-05
# Epoch 79/150
# 89/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9567 - loss: 0.1407
# Epoch 79: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9568 - loss: 0.1403 - val_accuracy: 0.8389 - val_loss: 0.6633 - learning_rate: 7.8125e-06
# Epoch 80/150
# 89/90 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9471 - loss: 0.1424
# Epoch 80: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9474 - loss: 0.1417 - val_accuracy: 0.8389 - val_loss: 0.6671 - learning_rate: 7.8125e-06
# Epoch 81/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9402 - loss: 0.1522
# Epoch 81: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9404 - loss: 0.1518 - val_accuracy: 0.8389 - val_loss: 0.6557 - learning_rate: 7.8125e-06
# Epoch 82/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9586 - loss: 0.1080
# Epoch 82: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9586 - loss: 0.1083 - val_accuracy: 0.8389 - val_loss: 0.6520 - learning_rate: 7.8125e-06
# Epoch 83/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9604 - loss: 0.1001
# Epoch 83: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9602 - loss: 0.1005 - val_accuracy: 0.8278 - val_loss: 0.6505 - learning_rate: 7.8125e-06
# Epoch 84/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9463 - loss: 0.1104
# Epoch 84: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9463 - loss: 0.1107 - val_accuracy: 0.8222 - val_loss: 0.6496 - learning_rate: 7.8125e-06
# Epoch 85/150
# 89/90 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9629 - loss: 0.1151
# Epoch 85: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 85: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - accuracy: 0.9630 - loss: 0.1151 - val_accuracy: 0.8222 - val_loss: 0.6634 - learning_rate: 7.8125e-06
# Epoch 86/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9609 - loss: 0.1212
# Epoch 86: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9609 - loss: 0.1212 - val_accuracy: 0.8222 - val_loss: 0.6622 - learning_rate: 3.9063e-06
# Epoch 87/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9652 - loss: 0.1060
# Epoch 87: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9651 - loss: 0.1059 - val_accuracy: 0.8222 - val_loss: 0.6625 - learning_rate: 3.9063e-06
# Epoch 88/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9623 - loss: 0.1145
# Epoch 88: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9623 - loss: 0.1143 - val_accuracy: 0.8222 - val_loss: 0.6562 - learning_rate: 3.9063e-06
# Epoch 89/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9624 - loss: 0.1120
# Epoch 89: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9623 - loss: 0.1122 - val_accuracy: 0.8222 - val_loss: 0.6484 - learning_rate: 3.9063e-06
# Epoch 90/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9518 - loss: 0.1273
# Epoch 90: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9521 - loss: 0.1267 - val_accuracy: 0.8278 - val_loss: 0.6487 - learning_rate: 3.9063e-06
# Epoch 91/150
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9558 - loss: 0.1146
# Epoch 91: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - accuracy: 0.9559 - loss: 0.1145 - val_accuracy: 0.8278 - val_loss: 0.6532 - learning_rate: 3.9063e-06
# Epoch 92/150
# 89/90 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9809 - loss: 0.0949
# Epoch 92: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
#
# Epoch 92: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.9807 - loss: 0.0948 - val_accuracy: 0.8222 - val_loss: 0.6555 - learning_rate: 3.9063e-06
# Epoch 93/150
# 88/90 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9526 - loss: 0.1051
# Epoch 93: val_loss did not improve from 0.56474
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.9528 - loss: 0.1051 - val_accuracy: 0.8222 - val_loss: 0.6599 - learning_rate: 1.9531e-06
# Epoch 93: early stopping
# Restoring model weights from the end of the best epoch: 43.
#
# Generating training plots...
# Evaluating model...
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 158ms/step
#
# ======================================================================
# TEST ACCURACY: 0.8500 (85.00%)
# ======================================================================
#
# Classification Report:
#                          precision    recall  f1-score   support
#
#          Moon_jellyfish       0.84      0.97      0.90        32
#        barrel_jellyfish       0.82      0.93      0.87        29
#          blue_jellyfish       0.74      0.71      0.72        24
#       compass_jellyfish       0.89      0.82      0.85        38
#    lions_mane_jellyfish       0.90      0.90      0.90        29
# mauve_stinger_jellyfish       0.91      0.75      0.82        28
#
#                accuracy                           0.85       180
#               macro avg       0.85      0.85      0.84       180
#            weighted avg       0.85      0.85      0.85       180
# ✓ Metrics saved to 'training_metrics.csv'
#
# ======================================================================
# Training completed successfully!
# ======================================================================
